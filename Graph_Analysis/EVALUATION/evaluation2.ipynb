# %%
from os import listdir
import json
import pandas as pd
import networkx as nx
import numpy as np

# %% [markdown]
# ## Helper functions

# %%
def load_terminology(terminology_file: str):
    """
    Returns a list of concepts given a txt file with a concept for each line
    """
    
    concepts = []
    
    with open(terminology_file, "r", encoding="utf-8") as f: 
        for line in f.readlines():
            concepts.append(line.split('\n')[0])
        
    return concepts
    

def find_all_pairs(concepts: list):
    """
    Returns a list of all possible pairs of concepts given a list of concepts
    (returns ALSO reflexive pairs with the same concept).
    """
    
    all_possibles = []
    
    for c1 in concepts:
        for c2 in concepts:
            # uncomment it to exclude reflexives
            #if c1 != c2:
            all_possibles.append((c1, c2))
            
    return all_possibles



def load_burst(allen_weights, threshold=0):
    """
    Reads a csv file with relations extracted with burst and returns a pandas dataframe. 
    Columns of the df: [prerequisite, advanced, weight].
    
    allen_weights can be 1 or "AIED".
    
    if allen_weights == 1 or "1":
        all weights are 1
    
    if == "AIED" or "aied":
        {'equals': 2, 'before': 5, 'after': 0, 'meets': 3, 'met-by': 0, 'overlaps': 7, 'overlapped-by': 1, 
        'during': 7, 'includes': 7, 'starts': 4, 'started-by': 2, 'finishes': 2, 'finished-by': 8}
    
    In both cases inverse relations are NOT used.
    
    Threshold: all relations with weight less or equal are discarded.
    """
    
    if allen_weights in [1, "1"]:
        # pesi = 1
        file_burst = "risultati_burst/edgelist_burst_prerequisites_con_collis_detect_pesi1.csv"
    elif allen_weights in ["AIED", "aied"]:
        #pesi = AIED
        file_burst = "risultati_burst/edgelist_burst_prerequisites_pesiAIED.csv"

    burst = pd.read_csv(file_burst, sep=",", index_col=0, encoding="utf-8")
    burst.rename({"X (prerequisite)": "prerequisite", "Y (subsidiary)": "advanced"}, axis=1, inplace=True)
    burst = burst[burst["weight"] > threshold]

    return burst

def load_bs(base_line_method: str, threshold):
    """
    Reads a csv file with relations extracted with BaseLine Methods and returns a pandas dataframe.
    Columns of the df: [prerequisite, advanced, weight].
    """
    file_bs = "BS/M5_1.csv"
    bs = pd.read_csv(file_bs, sep=";", encoding="utf-8", index_col=False)
    # bs.rename({ "lemma1": "advanced", "lemma2": "prerequisite", "m1": "weight" }, axis=1, inplace=True)
    # columns = ["index","prerequisite", "advanced", "m1", "m2", "m2_sentence","m3","m4","m4a","m4b","m5"]
    # bs = bs.reindex(columns=columns)
    bs.rename({ "m5": "weight" }, axis=1, inplace=True)

    bs = bs[bs["weight"] > threshold]
    # print(bs)

    return bs


def generate_gold(annotations: str, revisioned: bool):
    """
    Combines annotations taking only those relations with both concepts in the terminology. 
    
    revisioned:
        True
        False
        
    annotations:
        "nuove": le 4 annotazioni degli ultimi ragazzi:
        "vecchie": le annotazioni dei 2 ragazzi dell'anno scorso + le 4 nostre:
        "tutte". tutte le 10 annotazioni:
        
        
    Possible inputs:
    generate_gold(revisioned: True, "nuove")
    generate_gold(revisioned: True, "vecchie")
    generate_gold(revisioned: True, "tutte")
    generate_gold(revisioned: False, "nuove")
    generate_gold(revisioned: False, "vecchie")
    generate_gold(revisioned: False, "tutte")
    """
    
    
    gold = pd.DataFrame(columns=["prerequisite", "advanced", "count"])
    
    
    if not revisioned:
    
        if annotations == "nuove":
            input_dir = "annotazioni_originali/nuove/"
        elif annotations == "vecchie":
            input_dir = "annotazioni_originali/vecchie/"
        elif annotations == "tutte":
            input_dir = "annotazioni_originali/tutte/"


        for file in listdir(input_dir): 
            print(file)
            with open(input_dir+file, "r", encoding="utf-8") as f:

                data = json.load(f)["savedInsertedRelations"]
                print("\tNum of relations:", len(data), "\n")

                for rel in data:
                    # take only relations with both concepts in the terminology
                    if rel['prerequisite'] in concepts and rel['advanced'] in concepts:
                        # add a new row in the df if the relation is not present
                        if gold[(gold["prerequisite"] == rel['prerequisite']) & (gold["advanced"] == rel['advanced'])].shape[0] == 0:
                            gold.loc[gold.shape[0]] = [rel['prerequisite'], rel['advanced'], 1]
                        else:
                            # update the value of count in the df if the relation is already present
                            idx = gold[(gold["prerequisite"] == rel['prerequisite']) & (gold["advanced"] == rel['advanced'])].index[0]
                            gold.at[idx, "count"] = gold.at[idx, "count"] + 1

    
    if revisioned:
        
        if annotations == "nuove":
            input_dir = "annotazioni_revisionate/nuove/"
        elif annotations == "vecchie":
            input_dir = "annotazioni_revisionate/vecchie/"
        elif annotations == "tutte":
            input_dir = "annotazioni_revisionate/tutte/"

    
        for file in listdir(input_dir):
            print(file)
            # use only columns ["prerequisite", "advanced", "weight", "agreem", "revised"]
            curr_df = pd.read_csv(input_dir + file, sep=",", encoding="utf-8", usecols=[1, 2, 4, 5, 9]) 
                              
            # keep only relation with agreemen > 1 or those with agreement 1 but still present after revision
            curr_df = curr_df[(curr_df["agreem"] > 1) | (curr_df["Revised"].isin(["0.5", "0,5", "1", 1, 0.5]) ) ]
            print("\tNum of relations:", curr_df.shape[0], "\n")

            for i, rel in curr_df.iterrows():

                if rel['prerequisite'] in concepts and rel['advanced'] in concepts: 
                    # add a new row in the df if the relation is not present
                    if gold[(gold["prerequisite"] == rel['prerequisite']) & (gold["advanced"] == rel['advanced'])].shape[0] == 0:
                        gold.loc[gold.shape[0]] = [rel['prerequisite'], rel['advanced'], 1]
                    else:
                        # update the value of count in the df if the relation is already present
                        idx = gold[(gold["prerequisite"] == rel['prerequisite']) & (gold["advanced"] == rel['advanced'])].index[0]
                        gold.at[idx, "count"] = gold.at[idx, "count"] + 1


    print("\nNum of relations in the combined gold:", gold.shape[0])   
    
    return gold

    
def compute_metrics(automatic, manual):
    """
    Prints precision, recall and F1 score given TP FP TN and FN.
    """

    # results_df=pd.DataFrame(columns=["prerequisite","advanced","Direct Edge",	"Path",	"Not in Gold", "TP","TN","FP","FN"])
    results_list = []
    if type(automatic) == pd.DataFrame:
        automatic_edges = [tuple(x) for x in automatic[["prerequisite", "advanced"]].values]
        print("The compute metrics input automatic is a data frame")
    elif type(automatic) == nx.DiGraph:
        automatic_edges = list(automatic.edges())
        # print("The compute metrics input automatic is a Graph")
    else:
        print("Input error for 'automatic': accept only pd.DataFrame or nx.Digraph.")
        return None
    
    if type(manual) == pd.DataFrame:
        manual_edges = [tuple(x) for x in manual[["prerequisite", "advanced"]].values]
        # print("The compute metrics input manual is a data frame")
    elif type(manual) == nx.DiGraph:
         manual_edges = list(manual.edges())
         print("The compute metrics input manual is a Graph")
    else:
        print("Input error for 'manual': accept only pd.DataFrame or nx.Digraph.")
        return None
    
    
    
    all_possibles = find_all_pairs(concepts)
    
    
    TP = 0
    FP = 0
    TN = 0
    FN = 0
    HP = 0
    FNHP = 0

    for rel in automatic_edges:
        if rel in manual_edges:
            TP +=1
            # print("TP Direct rel:",rel)
            # ["prerequisite","advanced","Direct Edge",	"Path",	"Not in Gold", "TP","TN","FP","FN"]
            new_raw={'prerequisite':rel[0],'advanced':rel[1],'Direct Edge':1,'Path':0,'Not in Gold':0,"TP":1,"TN":0,"FP":0,"FN":0,"Path chain": '', "FN Path": 0}
            results_list.append(new_raw)
        elif manual.has_node(rel[0]) and manual.has_node(rel[1]):
            if nx.has_path(manual, rel[0], rel[1]):
                TP +=1
                HP +=1
                # print("There is a path between", rel)
                new_raw={'prerequisite':rel[0],'advanced':rel[1],'Direct Edge':0,'Path':1,'Not in Gold':0,"TP":1,"TN":0,"FP":0,"FN":0,"Path chain": nx.shortest_path(manual, rel[0], rel[1]), "FN Path": 0}
                results_list.append(new_raw)
            else:
                FP +=1
                # print("The relation does not exist in the Gold", rel)
                new_raw={'prerequisite':rel[0],'advanced':rel[1],'Direct Edge':0,'Path':0,'Not in Gold':0,"TP":0,"TN":0,"FP":1,"FN":0, "Path chain": '', "FN Path": 0}
                results_list.append(new_raw)
        elif rel not in manual_edges:
            FP +=1
            # print("FP: ",rel)
            new_raw={'prerequisite':rel[0],'advanced':rel[1],'Direct Edge':0,'Path':0,'Not in Gold':1,"TP":0,"TN":0,"FP":1,"FN":0, "Path chain": '', "FN Path": 0}
            results_list.append(new_raw)
        else:
            print("No defined criteria for: ",rel)

    # FN Missing rel, exist in gold but not extracted nor path
    for rel in manual_edges:
        # If gold rel not exist as a direct rel
        if rel not in automatic_edges:
            FN +=1
            new_raw={'prerequisite':rel[0],'advanced':rel[1],'Direct Edge':0,'Path':0,'Not in Gold':0,"TP":0,"TN":0,"FP":0,"FN":1, "Path chain": '', "FN Path": 0}
            results_list.append(new_raw)
        # If the concept in the extracted exist but there is no path
        elif automatic.has_node(rel[0]) and automatic.has_node(rel[1]):
            if not nx.has_path(automatic, rel[0], rel[1]):
                FN +=1
                FNHP +=1
                new_raw={'prerequisite':rel[0],'advanced':rel[1],'Direct Edge':0,'Path':0,'Not in Gold':0,"TP":0,"TN":0,"FP":0,"FN":1, "Path chain": '', "FN Path": 1}
                results_list.append(new_raw)
            else:
                print("For the gold relation there is also a path in the burst", rel)

    for rel in all_possibles:
        if rel not in manual_edges and rel not in automatic_edges: 
            TN +=1
            new_raw={'prerequisite':rel[0],'advanced':rel[1],'Direct Edge':0,'Path':0,'Not in Gold':0,"TP":0,"TN":1,"FP":0,"FN":0, "Path chain": '', "FN Path": 0}
            results_list.append(new_raw)



    results_df = pd.DataFrame(results_list,columns=["prerequisite","advanced","Direct Edge",	"Path",	"Not in Gold", "TP","TN","FP","FN", "Path chain", "FN Path"])
    results_df.to_csv("burst_FN_path_results.csv", sep=";", encoding="utf-8")
    precision = TP / (TP + FP)
    recall = TP / (TP + FN)
    print("\nTP =", TP, "\nFP =", FP, "\nTN =", TN, "\nFN =", FN,"\nFNHP =", FNHP, "precision =", precision, "\nrecall =", recall)
    F1_score = 2 * ( (precision * recall) / (precision + recall) )
    print("precision =", precision, "\nrecall =", recall, "\nF1 =", F1_score)
    print("number of paths TP",HP)
    # nx.draw(manual)
    


def compute_trans_closure_metrics(automatic, manual):
    """
    Prints precision, recall and F1 score given TP FP TN and FN.
    """

    # results_df=pd.DataFrame(columns=["prerequisite","advanced","Direct Edge",	"Path",	"Not in Gold", "TP","TN","FP","FN"])
    results_list = []
    if type(automatic) == pd.DataFrame:
        automatic_edges = [tuple(x) for x in automatic[["prerequisite", "advanced"]].values]
        print("The compute metrics input automatic is a data frame")
    elif type(automatic) == nx.DiGraph:
        automatic_edges = list(automatic.edges())
        # print("The compute metrics input automatic is a Graph")
    else:
        print("Input error for 'automatic': accept only pd.DataFrame or nx.Digraph.")
        return None

    if type(manual) == pd.DataFrame:
        manual_edges = [tuple(x) for x in manual[["prerequisite", "advanced"]].values]
        # print("The compute metrics input manual is a data frame")
    elif type(manual) == nx.DiGraph:
         manual_edges = list(manual.edges())
         print("The compute metrics input manual is a Graph")
    else:
        print("Input error for 'manual': accept only pd.DataFrame or nx.Digraph.")
        return None



    all_possibles = find_all_pairs(concepts)


    TP = 0
    FP = 0
    TN = 0
    FN = 0
    HP = 0
    FNHP = 0

    for rel in automatic_edges:
        if rel in manual_edges:
            TP +=1
            # print("TP Direct rel:",rel)
            # ["prerequisite","advanced","Direct Edge",	"Path",	"Not in Gold", "TP","TN","FP","FN"]
            new_raw={'prerequisite':rel[0],'advanced':rel[1],'Direct Edge':1,'Path':0,'Not in Gold':0,"TP":1,"TN":0,"FP":0,"FN":0,"Path chain": '', "FN Path": 0}
            results_list.append(new_raw)
        elif manual.has_node(rel[0]) and manual.has_node(rel[1]):
            if nx.has_path(manual, rel[0], rel[1]):
                TP +=1
                HP +=1
                # print("There is a path between", rel)
                new_raw={'prerequisite':rel[0],'advanced':rel[1],'Direct Edge':0,'Path':1,'Not in Gold':0,"TP":1,"TN":0,"FP":0,"FN":0,"Path chain": nx.shortest_path(manual, rel[0], rel[1]), "FN Path": 0}
                results_list.append(new_raw)
            else:
                FP +=1
                # print("The relation does not exist in the Gold", rel)
                new_raw={'prerequisite':rel[0],'advanced':rel[1],'Direct Edge':0,'Path':0,'Not in Gold':0,"TP":0,"TN":0,"FP":1,"FN":0, "Path chain": '', "FN Path": 0}
                results_list.append(new_raw)
        elif rel not in manual_edges:
            FP +=1
            # print("FP: ",rel)
            new_raw={'prerequisite':rel[0],'advanced':rel[1],'Direct Edge':0,'Path':0,'Not in Gold':1,"TP":0,"TN":0,"FP":1,"FN":0, "Path chain": '', "FN Path": 0}
            results_list.append(new_raw)
        else:
            print("No defined criteria for: ",rel)

    # FN Missing rel, exist in gold but not extracted nor path
    # for rel in manual_edges:
    #     # If gold rel not exist as a direct rel
    #     if rel not in automatic_edges:
    #         FN +=1
    #         new_raw={'prerequisite':rel[0],'advanced':rel[1],'Direct Edge':0,'Path':0,'Not in Gold':0,"TP":0,"TN":0,"FP":0,"FN":1, "Path chain": '', "FN Path": 0}
    #         results_list.append(new_raw)
    #     # If the concept in the extracted exist but there is no path
    #     elif automatic.has_node(rel[0]) and automatic.has_node(rel[1]):
    #         if not nx.has_path(automatic, rel[0], rel[1]):
    #             FN +=1
    #             FNHP +=1
    #             new_raw={'prerequisite':rel[0],'advanced':rel[1],'Direct Edge':0,'Path':0,'Not in Gold':0,"TP":0,"TN":0,"FP":0,"FN":1, "Path chain": '', "FN Path": 1}
    #             results_list.append(new_raw)
    #         else:
    #             print("For the gold relation there is also a path in the burst", rel)

    # FN Missing rel, exist in gold as path but not extracted nor path
    manual_t = nx.transitive_closure(manual, reflexive=False)
    manual_t_edges = list(manual_t.edges())
    for rel in manual_t_edges:
        # If gold rel not exist as a direct rel
        if rel not in automatic_edges:
            FN +=1
            new_raw={'prerequisite':rel[0],'advanced':rel[1],'Direct Edge':0,'Path':0,'Not in Gold':0,"TP":0,"TN":0,"FP":0,"FN":1, "Path chain": '', "FN Path": 0}
            results_list.append(new_raw)
        # If the concept in the extracted exist but there is no path
        elif automatic.has_node(rel[0]) and automatic.has_node(rel[1]):
            if not nx.has_path(automatic, rel[0], rel[1]):
                FN +=1
                FNHP +=1
                new_raw={'prerequisite':rel[0],'advanced':rel[1],'Direct Edge':0,'Path':0,'Not in Gold':0,"TP":0,"TN":0,"FP":0,"FN":1, "Path chain": '', "FN Path": 1}
                results_list.append(new_raw)
            else:
                print("For the gold relation there is also a path in the burst", rel)

    for rel in all_possibles:
        if rel not in manual_edges and rel not in automatic_edges:
            TN +=1
            new_raw={'prerequisite':rel[0],'advanced':rel[1],'Direct Edge':0,'Path':0,'Not in Gold':0,"TP":0,"TN":1,"FP":0,"FN":0, "Path chain": '', "FN Path": 0}
            results_list.append(new_raw)



    results_df = pd.DataFrame(results_list,columns=["prerequisite","advanced","Direct Edge",	"Path",	"Not in Gold", "TP","TN","FP","FN", "Path chain", "FN Path"])
    results_df.to_csv("burst_FN_path_results.csv", sep=";", encoding="utf-8")
    precision = TP / (TP + FP)
    recall = TP / (TP + FN)
    print("\nTP =", TP, "\nFP =", FP, "\nTN =", TN, "\nFN =", FN,"\nFNHP =", FNHP, "precision =", precision, "\nrecall =", recall)
    F1_score = 2 * ( (precision * recall) / (precision + recall) )
    print("precision =", precision, "\nrecall =", recall, "\nF1 =", F1_score)
    print("number of paths TP",HP)
    # nx.draw(manual)



def build_freq_matrix(index_df, save=False):
    """
    Builds an undirected square matrix with weights based on concepts co-occurrence in a window of +/- 3 sentences.
    
    index_df: index df with columns ["Lemma", "idFrase", "idParolaStart"]
    """
    
    freq_df = pd.DataFrame(0, index=concepts, columns=concepts)

    for c1 in index_df["Lemma"].unique().tolist():
        # subset with only occurrences of c1
        sub_df_c1 = index_df[index_df["Lemma"] == c1]
        for i, r in sub_df_c1.iterrows():
            curr_sent = r["idFrase"]

            for c2 in index_df["Lemma"].unique().tolist():
                if c2 != c1:
                    # subset with only occurrences of c2
                    sub_df_c2 = index_df[index_df["Lemma"] == c2]
                    count = sub_df_c2[sub_df_c2["idFrase"].isin(list(range(curr_sent-3, curr_sent+4)))].shape[0]

                    freq_df.at[c1, c2] = freq_df.at[c1, c2] + count
                    
    if save:
        freq_df.to_csv("risultati_freq\\freq.csv", sep="\t", encoding="utf-8")
        
    return freq_df
    

def create_graphs(dataset):
    """
    Returns a networkx graph from a pandas dataframe with columns ["prerequisite", "advanced"]
    """

    G_nx = nx.DiGraph()

    for i, r in dataset.iterrows():
        G_nx.add_edge(r["prerequisite"], r["advanced"])

    return G_nx



def detect_and_remove_cycles(graph):
    """
    Recursively detect and delete cycles from the graph of the gold.
    First it automatically remove 2-nodes-cycles (i.e. recirpocal) if these are present, 
    by using annotators agreement or, if agreement is equal in both directions, 
    temporal order of concepts appearance in the text.
    Then it prompts user to manually decide which edge remove inside 3(or more)-nodes-cycles.
    
    Finally returns the graph with no cycles.
    
    """
    
    G_gold_no_trans = graph.copy()
    
    # detect simple cycles (i.e. closed paths with 2 or more nodes where no node appears twice)
    cycles = list(nx.simple_cycles(G_gold_no_trans))

    print("Number of cycles found:\t", len(cycles))

    def find_longest_cycle(cycles_list):
        """lenght of the cycles measured in number of nodes"""
        list_len = [len(i) for i in cycles_list]
        return max(list_len)
    
    def find_shortest_cycle(cycles_list):
        """lenght of the cycles measured in number of nodes"""
        list_len = [len(i) for i in cycles_list]
        return min(list_len)
    

    if len(cycles) == 0:
        # no cycles have been found
        return G_gold_no_trans


    print("Number of nodes in the longest cycle:", find_longest_cycle(cycles), "\n")

    reciprocal_cycles = [x for x in cycles if len(x) == 2]
    
    if len(reciprocal_cycles) > 0:
        
        print("Found cycles with only 2 nodes that will be fixed automatically using annotators agreement or temporal order of occurrence.\n")

        for cycle in reciprocal_cycles:
            print("\tAnalyzing cycle:\t", cycle)
            c1 = cycle[0]
            c2 = cycle[1]

            # check agreement in the gold
            from_c1_to_c2 = gold[(gold["prerequisite"] == c1) & (gold["advanced"] == c2)].iloc[0]["count"]
            from_c2_to_c1 = gold[(gold["prerequisite"] == c2) & (gold["advanced"] == c1)].iloc[0]["count"]

            if from_c1_to_c2 > from_c2_to_c1:
                G_gold_no_trans.remove_edge(c2, c1)
                print("\tremoved:\t", c2, "\t-->\t", c1)
                print("\tcriterion: agreement\n")
            elif from_c2_to_c1 > from_c1_to_c2:
                G_gold_no_trans.remove_edge(c1, c2)
                print("\tremoved:\t", c1, "\t-->\t", c2)
                print("\tcriterion: agreement\n")
            elif from_c1_to_c2 == from_c2_to_c1:
                # edges have the same agreement: use temporal order to decide
                if index_df[index_df["Lemma"] == c1]["idFrase"].min() < index_df[index_df["Lemma"] == c2]["idFrase"].min():
                    G_gold_no_trans.remove_edge(c2, c1)
                    print("\tremoved:\t", c2, "\t-->\t", c1)
                    print("\tcriterion: temporal order\n")
                elif index_df[index_df["Lemma"] == c2]["idFrase"].min() < index_df[index_df["Lemma"] == c1]["idFrase"].min():
                    G_gold_no_trans.remove_edge(c1, c2)
                    print("\tremoved:\t", c1, "\t-->\t", c2)
                    print("\tcriterion: temporal order\n")
                elif index_df[index_df["Lemma"] == c2]["idFrase"].min() == index_df[index_df["Lemma"] == c1]["idFrase"].min():
                    # occur in the same sentence: check number of token
                    same_sent = index_df[index_df["Lemma"] == c2]["idFrase"].min() 
                    sent_sub_df_c1 = index_df[(index_df["Lemma"] == c1) & (index_df["idFrase"] == same_sent)]
                    sent_sub_df_c2 = index_df[(index_df["Lemma"] == c2) & (index_df["idFrase"] == same_sent)]

                    if sent_sub_df_c1["idParolaStart"].min() < sent_sub_df_c2["idParolaStart"].min():
                        G_gold_no_trans.remove_edge(c2, c1)
                        print("\tremoved:\t", c2, "\t-->\t", c1)
                        print("\tcriterion: temporal order\n")
                    elif sent_sub_df_c2["idParolaStart"].min() < sent_sub_df_c1["idParolaStart"].min():
                        G_gold_no_trans.remove_edge(c1, c2)
                        print("\tremoved:\t", c1, "\t-->\t", c2)
                        print("\tcriterion: temporal order\n")
                    else:
                        print("\tnot captured:\n", c1, "\t-->\t", c2, "\nand viceversa.\n")

            else:
                print("\tnot captured:\n", c1, "\t-->\t", c2, "\nand viceversa.\n")
         
        print("Finished to fix cycles with 2 nodes. Cycles will be now detected again in the new graph.\n")
        # recursively call the function to update the list of cycles to fix
        detect_and_remove_cycles(G_gold_no_trans)
                
    else:
        print("There are no cycles with only 2 nodes. You need to choose manually which edge remove.\n")
              
        shortest_cycles = [x for x in cycles if len(x) == find_shortest_cycle(cycles)]
    
        first_cycle = shortest_cycles[0]

        edges_list = []

        for node in range(len(first_cycle)):
            try:
                edges_list.append((first_cycle[node], first_cycle[node+1]))
            except IndexError:
                edges_list.append((first_cycle[node], first_cycle[0]))

        print("\tAnalyzing cycle:\n")

        for i, x in enumerate(edges_list):
             print("\t", i, ":", x)

        choice = int(input("\tInsert the number of the edge to remove:\t"))

        to_remove = edges_list[choice]

        G_gold_no_trans.remove_edge(to_remove[0], to_remove[1])
        print("\tremoved:\t", to_remove[0], "\t-->\t", to_remove[1], "\n")

        print("Fixed one cycle with more than 2 nodes. Cycles will be now detected again in the new graph.\n")
        # recursively call the function to update the list of cycles to fix
        detect_and_remove_cycles(G_gold_no_trans)
            
            
    return G_gold_no_trans

# %% [markdown]
# ## Open data

# %%
# load terminology
terminology_file = "new_terminologia_pret_v2_3.txt"
concepts = load_terminology(terminology_file)        
all_possibles = find_all_pairs(concepts)
# load burst
burst = load_burst(allen_weights=1, threshold=0)
# load gold
gold = generate_gold("nuove", True)
# load bs
bs = load_bs("m5", threshold=0.0)

# select top burst relations
# top= 100
# select top n burst (n=number of relations in the gold)
# top = gold.shape[0]
#gold = gold.sort_values(by="count", ascending=False).iloc[:top]
# burst_top = burst.sort_values(by="weight", ascending=False).iloc[:top]
# print("\nnumber of relations in the top burst", top)
print("\nRelations with the same weight of the last relation in the top list that were excluded from the top chart:")
#burst[burst["weight"] == burst_top["weight"].min()]
# Out:
# Revisione_Annotazione2020_Sava.csv
# 	Num of relations: 130
#
# Revisione_Annotazione2020_Mirenda.csv
# 	Num of relations: 236
#
# Revisione_Annotazione2020_Parizzi.csv
# 	Num of relations: 143
#
# Revisione_Annotazione2020_Moggio.csv
# 	Num of relations: 184
#
#
# Num of relations in the combined gold: 350
#
# Relations with the same weight of the last relation in the top list that were excluded from the top chart:

# %%
# bs_graph = create_graphs(bs)
burst_graph = create_graphs(burst)
gold_graph = create_graphs(gold)
# compute_metrics(bs_graph, gold_graph)
compute_metrics(burst_graph, gold_graph)
# Out:
# The compute metrics input manual is a Graph
# For the gold relation there is also a path in the burst ('INTERNET', 'PROTOCOL')
# For the gold relation there is also a path in the burst ('INTERNET', 'TRADITIONAL TELEPHONE')
# For the gold relation there is also a path in the burst ('INTERNET', 'TIER-1 INTERNET SERVICE PROVIDER')
# For the gold relation there is also a path in the burst ('INTERNET', 'TIER-2 INTERNET SERVICE PROVIDER')
# For the gold relation there is also a path in the burst ('INTERNET', 'INTRANET')
# For the gold relation there is also a path in the burst ('INTERNET', 'TIER-3 INTERNET SERVICE PROVIDER')
# For the gold relation there is also a path in the burst ('INTERNET', 'WEBSERVERS')
# For the gold relation there is also a path in the burst ('INTERNET', 'GATEWAY')
# For the gold relation there is also a path in the burst ('INTERNET', 'INTERNET SERVICE PROVIDER')
# For the gold relation there is also a path in the burst ('INTERNET', 'ACCESS INTERNET SERVICE PROVIDER')
# For the gold relation there is also a path in the burst ('INTERNET', 'BROWSER')
# For the gold relation there is also a path in the burst ('INTERNET', 'VOICE OVER INTERNET PROTOCOL')
# For the gold relation there is also a path in the burst ('INTERNET', 'INTERNET INFRASTRUCTURE')
# For the gold relation there is also a path in the burst ('INTERNET', 'CERTIFICATE AUTHORITY')
# For the gold relation there is also a path in the burst ('INTERNET', 'INTERNET2')
# For the gold relation there is also a path in the burst ('INTERNET', 'INTERNET PROTOCOL ADDRESS')
# For the gold relation there is also a path in the burst ('INTERNET', 'EMAIL')
# For the gold relation there is also a path in the burst ('INTERNET', 'WORLD WIDE WEB')
# For the gold relation there is also a path in the burst ('INTERNET', 'ROUTER')
# For the gold relation there is also a path in the burst ('INTERNET', 'TRANSMISSION CONTROL PROTOCOL')
# For the gold relation there is also a path in the burst ('INTERNET', 'HOP COUNT')
# For the gold relation there is also a path in the burst ('INTERNET', 'INTERNET PROTOCOL')
# For the gold relation there is also a path in the burst ('INTERNET', '4G')
# For the gold relation there is also a path in the burst ('INTERNET', 'CONTENT DELIVERY NETWORK')
# For the gold relation there is also a path in the burst ('INTERNET', 'INTERNET SOFTWARE')
# For the gold relation there is also a path in the burst ('INTERNET', 'ENCRYPTION')
# For the gold relation there is also a path in the burst ('INTERNET', 'ADDRESSING SYSTEM')
# For the gold relation there is also a path in the burst ('INTERNET', 'APPLICATION LAYER')
# For the gold relation there is also a path in the burst ('INTERNET', 'DOMAIN')
# For the gold relation there is also a path in the burst ('INTERNET', 'END USER')
# For the gold relation there is also a path in the burst ('INTERNET', 'PHONE NETWORK')
# For the gold relation there is also a path in the burst ('INTERNET', 'SECOND GENERATION')
# For the gold relation there is also a path in the burst ('INTERNET', '3G')
# For the gold relation there is also a path in the burst ('INTERNET', 'SECURE SHELL')
# For the gold relation there is also a path in the burst ('INTERNET', 'NETWORK LAYER')
# For the gold relation there is also a path in the burst ('INTERNET', 'LINK LAYER')
# For the gold relation there is also a path in the burst ('INTERNET', 'BIT PATTERN')
# For the gold relation there is also a path in the burst ('INTERNET', 'DIGITAL SIGNATURE')
# For the gold relation there is also a path in the burst ('INTERNET', 'NAME SERVER')
# For the gold relation there is also a path in the burst ('INTERNET', 'DOMAIN NAME SYSTEM')
# For the gold relation there is also a path in the burst ('INTERNET', 'PORT NUMBER')
# For the gold relation there is also a path in the burst ('INTERNET', 'TRANSPORT LAYER')
# For the gold relation there is also a path in the burst ('INTERNET', 'FORWARDING TABLE')
# For the gold relation there is also a path in the burst ('INTERNET', 'MNEMONIC DOMAIN NAME')
# For the gold relation there is also a path in the burst ('INTERNET', 'DOMAIN NAME')
# For the gold relation there is also a path in the burst ('INTERNET', 'REGISTERED DOMAIN')
# For the gold relation there is also a path in the burst ('INTERNET', 'INTERNET PROTOCOL NETWORK')
# For the gold relation there is also a path in the burst ('INTERNET', 'HYPERTEXT TRANSFER PROTOCOL')
# For the gold relation there is also a path in the burst ('INTERNET', 'INSTANT MESSAGING')
# For the gold relation there is also a path in the burst ('INTERNET', 'SECURE SOCKET LAYER')
# For the gold relation there is also a path in the burst ('INTERNET', 'SIMPLE MAIL TRANSFER PROTOCOL')
# For the gold relation there is also a path in the burst ('INTERNET', 'REMOTE MAIL SERVER')
# For the gold relation there is also a path in the burst ('INTERNET', 'MAIL SERVER')
# For the gold relation there is also a path in the burst ('INTERNET', 'INTERNET MAIL ACCESS PROTOCOL')
# For the gold relation there is also a path in the burst ('INTERNET', 'TRANSMISSION CONTROL PROTOCOL/INTERNET PROTOCOL NETWORK')
# For the gold relation there is also a path in the burst ('INTERNET', 'NETWORK NEWS TRANSFER PROTOCOL')
# For the gold relation there is also a path in the burst ('INTERNET', 'HYPERTEXT')
# For the gold relation there is also a path in the burst ('INTERNET', 'HYPERTEXT DOCUMENT')
# For the gold relation there is also a path in the burst ('INTERNET', 'UNIFORM RESOURCE LOCATOR')
# For the gold relation there is also a path in the burst ('INTERNET', 'HYPERTEXT MARKUP LANGUAGE')
# For the gold relation there is also a path in the burst ('INTERNET', 'TAG')
# For the gold relation there is also a path in the burst ('INTERNET', 'HEAD')
# For the gold relation there is also a path in the burst ('INTERNET', 'BODY')
# For the gold relation there is also a path in the burst ('INTERNET', 'WEBSERVER')
# For the gold relation there is also a path in the burst ('INTERNET', 'DENIAL OF SERVICE')
# For the gold relation there is also a path in the burst ('INTERNET', 'END SYSTEM')
# For the gold relation there is also a path in the burst ('INTERNET', 'CERTIFICATE')
# For the gold relation there is also a path in the burst ('INTERNET', 'PRIVATE-KEY')
# For the gold relation there is also a path in the burst ('INTERNET', 'PUBLIC-KEY ENCRYPTION')
# For the gold relation there is also a path in the burst ('INTERNET', 'PUBLIC-KEY')
# For the gold relation there is also a path in the burst ('PROTOCOL', 'CARRIER SENSE , MULTIPLE ACCESS WITH COLLISION DETECTION')
# For the gold relation there is also a path in the burst ('PROTOCOL', 'HYPERTEXT TRANSFER PROTOCOL')
# For the gold relation there is also a path in the burst ('PROTOCOL', 'COLLISION AVOIDANCE')
# For the gold relation there is also a path in the burst ('PROTOCOL', 'DOMAIN NAME SYSTEM')
# For the gold relation there is also a path in the burst ('PROTOCOL', 'SIMPLE MAIL TRANSFER PROTOCOL')
# For the gold relation there is also a path in the burst ('PROTOCOL', 'VOICE OVER INTERNET PROTOCOL')
# For the gold relation there is also a path in the burst ('PROTOCOL', 'TRANSMISSION CONTROL PROTOCOL')
# For the gold relation there is also a path in the burst ('PROTOCOL', 'INTERNET PROTOCOL')
# For the gold relation there is also a path in the burst ('PROTOCOL', 'USER DATAGRAM PROTOCOL')
# For the gold relation there is also a path in the burst ('PROTOCOL', 'NETWORK NEWS TRANSFER PROTOCOL')
# For the gold relation there is also a path in the burst ('PROTOCOL', 'POST OFFICE PROTOCOL VERSION 3')
# For the gold relation there is also a path in the burst ('PROTOCOL', 'INTERNET MAIL ACCESS PROTOCOL')
# For the gold relation there is also a path in the burst ('PROTOCOL', 'WORLD WIDE WEB')
# For the gold relation there is also a path in the burst ('PROTOCOL', 'UNIFORM RESOURCE LOCATOR')
# For the gold relation there is also a path in the burst ('PROTOCOL', 'TRANSMISSION CONTROL PROTOCOL/INTERNET PROTOCOL NETWORK')
# For the gold relation there is also a path in the burst ('PROTOCOL', 'APPLICATION LAYER')
# For the gold relation there is also a path in the burst ('PROTOCOL', 'NETWORK LAYER')
# For the gold relation there is also a path in the burst ('PROTOCOL', 'INTERNET PROTOCOL ADDRESS')
# For the gold relation there is also a path in the burst ('PROTOCOL', 'NAME SERVER')
# For the gold relation there is also a path in the burst ('PROTOCOL', 'TRANSPORT LAYER')
# For the gold relation there is also a path in the burst ('PROTOCOL', 'FORWARDING TABLE')
# For the gold relation there is also a path in the burst ('PROTOCOL', 'DOMAIN')
# For the gold relation there is also a path in the burst ('PROTOCOL', 'DOMAIN NAME')
# For the gold relation there is also a path in the burst ('PROTOCOL', 'INTERNET PROTOCOL NETWORK')
# For the gold relation there is also a path in the burst ('PROTOCOL', 'HOP COUNT')
# For the gold relation there is also a path in the burst ('PROTOCOL', 'END USER')
# For the gold relation there is also a path in the burst ('PROTOCOL', 'INSTANT MESSAGING')
# For the gold relation there is also a path in the burst ('PROTOCOL', 'REMOTE MAIL SERVER')
# For the gold relation there is also a path in the burst ('PROTOCOL', 'MAIL SERVER')
# For the gold relation there is also a path in the burst ('PROTOCOL', 'HYPERTEXT')
# For the gold relation there is also a path in the burst ('PROTOCOL', 'HYPERTEXT DOCUMENT')
# For the gold relation there is also a path in the burst ('PROTOCOL', 'HYPERTEXT MARKUP LANGUAGE')
# For the gold relation there is also a path in the burst ('PROTOCOL', 'TAG')
# For the gold relation there is also a path in the burst ('PROTOCOL', 'HEAD')
# For the gold relation there is also a path in the burst ('PROTOCOL', 'BODY')
# For the gold relation there is also a path in the burst ('PROTOCOL', 'WEBSERVER')
# For the gold relation there is also a path in the burst ('PROTOCOL', 'WEBSERVERS')
# For the gold relation there is also a path in the burst ('PROTOCOL', 'BROWSER')
# For the gold relation there is also a path in the burst ('PROTOCOL', 'TRADITIONAL TELEPHONE')
# For the gold relation there is also a path in the burst ('PROTOCOL', 'INTERNET SERVICE PROVIDER')
# For the gold relation there is also a path in the burst ('PROTOCOL', 'EMAIL')
# For the gold relation there is also a path in the burst ('PROTOCOL', 'ROUTER')
# For the gold relation there is also a path in the burst ('PROTOCOL', 'MNEMONIC ADDRESS')
# For the gold relation there is also a path in the burst ('TRADITIONAL TELEPHONE', 'SECOND GENERATION')
# For the gold relation there is also a path in the burst ('TRADITIONAL TELEPHONE', '1G')
# For the gold relation there is also a path in the burst ('TRADITIONAL TELEPHONE', 'PHONE NETWORK')
# For the gold relation there is also a path in the burst ('TRADITIONAL TELEPHONE', '4G')
# For the gold relation there is also a path in the burst ('TRADITIONAL TELEPHONE', '3G')
# For the gold relation there is also a path in the burst ('TRADITIONAL TELEPHONE', 'INTERNET PROTOCOL NETWORK')
# For the gold relation there is also a path in the burst ('CLIENT', 'PEER-TO-PEER MODEL')
# For the gold relation there is also a path in the burst ('CLIENT', 'WEBSERVER')
# For the gold relation there is also a path in the burst ('CLIENT', 'SERVLETS')
# For the gold relation there is also a path in the burst ('CLIENT', 'FIREWALL')
# For the gold relation there is also a path in the burst ('CLIENT', 'CLIENT/SERVER MODEL')
# For the gold relation there is also a path in the burst ('CLIENT', 'CLIENT-SIDE')
# For the gold relation there is also a path in the burst ('CLIENT', 'PROXY SERVER')
# For the gold relation there is also a path in the burst ('CLIENT', 'SERVER-SIDE')
# For the gold relation there is also a path in the burst ('CLIENT', 'PHP')
# For the gold relation there is also a path in the burst ('CLIENT', 'HYPERTEXT TRANSFER PROTOCOL')
# For the gold relation there is also a path in the burst ('CLIENT', 'JAVASERVER PAGE')
# For the gold relation there is also a path in the burst ('CLIENT', 'ACTIVE SERVER PAGE')
# For the gold relation there is also a path in the burst ('CLIENT', 'AUDITING SOFTWARE')
# For the gold relation there is also a path in the burst ('CLIENT', 'UNIFORM RESOURCE LOCATOR')
# For the gold relation there is also a path in the burst ('CLIENT', 'HYPERTEXT MARKUP LANGUAGE')
# For the gold relation there is also a path in the burst ('CLIENT', 'SEARCH ENGINE')
# For the gold relation there is also a path in the burst ('CLIENT', 'TAG')
# For the gold relation there is also a path in the burst ('CLIENT', 'BROWSER')
# For the gold relation there is also a path in the burst ('TIER-1 INTERNET SERVICE PROVIDER', 'TIER-2 INTERNET SERVICE PROVIDER')
# For the gold relation there is also a path in the burst ('TIER-2 INTERNET SERVICE PROVIDER', 'TIER-3 INTERNET SERVICE PROVIDER')
# For the gold relation there is also a path in the burst ('INTERNET PROTOCOL', 'INTERNET PROTOCOL NETWORK')
# For the gold relation there is also a path in the burst ('INTERNET PROTOCOL', 'BIT PATTERN')
# For the gold relation there is also a path in the burst ('INTERNET PROTOCOL', 'USER DATAGRAM PROTOCOL')
# For the gold relation there is also a path in the burst ('INTERNET PROTOCOL', 'APPLICATION LAYER')
# For the gold relation there is also a path in the burst ('INTERNET PROTOCOL', 'NETWORK LAYER')
# For the gold relation there is also a path in the burst ('INTERNET PROTOCOL', 'HOP COUNT')
# For the gold relation there is also a path in the burst ('INTERNET PROTOCOL', 'TRANSPORT LAYER')
# For the gold relation there is also a path in the burst ('INTERNET PROTOCOL', 'TRANSMISSION CONTROL PROTOCOL')
# For the gold relation there is also a path in the burst ('INTERNET PROTOCOL', 'FORWARDING TABLE')
# For the gold relation there is also a path in the burst ('INTERNET PROTOCOL ADDRESS', 'BIT PATTERN')
# For the gold relation there is also a path in the burst ('INTERNET PROTOCOL ADDRESS', 'NAME SERVER')
# For the gold relation there is also a path in the burst ('INTERNET PROTOCOL ADDRESS', 'DOMAIN NAME SYSTEM')
# For the gold relation there is also a path in the burst ('INTERNET PROTOCOL ADDRESS', 'INTERNET PROTOCOL')
# For the gold relation there is also a path in the burst ('INTERNET PROTOCOL ADDRESS', 'DOMAIN')
# For the gold relation there is also a path in the burst ('INTERNET PROTOCOL ADDRESS', 'SUBDOMAINS')
# For the gold relation there is also a path in the burst ('INTERNET PROTOCOL ADDRESS', 'MNEMONIC DOMAIN NAME')
# For the gold relation there is also a path in the burst ('INTERNET PROTOCOL ADDRESS', 'TOP-LEVEL DOMAINS')
# For the gold relation there is also a path in the burst ('INTERNET PROTOCOL ADDRESS', 'DOMAIN NAME')
# For the gold relation there is also a path in the burst ('INTERNET PROTOCOL ADDRESS', 'REGISTERED DOMAIN')
# For the gold relation there is also a path in the burst ('INTRANET', 'FIREWALL')
# For the gold relation there is also a path in the burst ('INTRANET', 'AUDITING SOFTWARE')
# For the gold relation there is also a path in the burst ('HYPERTEXT TRANSFER PROTOCOL', 'END USER')
# For the gold relation there is also a path in the burst ('HYPERTEXT TRANSFER PROTOCOL', 'INSTANT MESSAGING')
# For the gold relation there is also a path in the burst ('HYPERTEXT TRANSFER PROTOCOL', 'SECURE SOCKET LAYER')
# For the gold relation there is also a path in the burst ('NETWORK', 'SIMPLE MAIL TRANSFER PROTOCOL')
# For the gold relation there is also a path in the burst ('NETWORK', 'INTERPROCESS COMMUNICATION')
# For the gold relation there is also a path in the burst ('NETWORK', 'CONTENT DELIVERY NETWORK')
# For the gold relation there is also a path in the burst ('NETWORK', 'OPEN NETWORK')
# For the gold relation there is also a path in the burst ('NETWORK', 'ROUTER')
# For the gold relation there is also a path in the burst ('NETWORK', 'DISTRIBUTED SYSTEM')
# For the gold relation there is also a path in the burst ('NETWORK', 'PHONE NETWORK')
# For the gold relation there is also a path in the burst ('NETWORK', 'PERSONAL AREA NETWORK')
# For the gold relation there is also a path in the burst ('NETWORK', 'LOCAL AREA NETWORK')
# For the gold relation there is also a path in the burst ('NETWORK', 'METROPOLITAN AREA NETWORK')
# For the gold relation there is also a path in the burst ('NETWORK', 'WIDE AREA NETWORK')
# For the gold relation there is also a path in the burst ('NETWORK', 'INTERNET')
# For the gold relation there is also a path in the burst ('NETWORK', 'BUS')
# For the gold relation there is also a path in the burst ('NETWORK', 'STAR')
# For the gold relation there is also a path in the burst ('NETWORK', 'PROTOCOL')
# For the gold relation there is also a path in the burst ('NETWORK', 'MALICIOUS SOFTWARE')
# For the gold relation there is also a path in the burst ('NETWORK', 'ANTIVIRUS SOFTWARE')
# For the gold relation there is also a path in the burst ('NETWORK', 'WORM')
# For the gold relation there is also a path in the burst ('NETWORK', 'AUDITING SOFTWARE')
# For the gold relation there is also a path in the burst ('NETWORK', 'GATEWAY')
# For the gold relation there is also a path in the burst ('NETWORK', 'INTERNET SERVICE PROVIDER')
# For the gold relation there is also a path in the burst ('NETWORK', '4G')
# For the gold relation there is also a path in the burst ('NETWORK', 'CLIENT/SERVER MODEL')
# For the gold relation there is also a path in the burst ('NETWORK', 'ETHERNET NETWORK')
# For the gold relation there is also a path in the burst ('NETWORK', 'WIRELESS NETWORK')
# For the gold relation there is also a path in the burst ('NETWORK', 'WIFI NETWORK')
# For the gold relation there is also a path in the burst ('NETWORK', 'END SYSTEM')
# For the gold relation there is also a path in the burst ('NETWORK', 'SERVER')
# For the gold relation there is also a path in the burst ('NETWORK', 'REMOTE MAIL SERVER')
# For the gold relation there is also a path in the burst ('NETWORK', 'MAIL SERVER')
# For the gold relation there is also a path in the burst ('NETWORK', 'FORWARDING TABLE')
# For the gold relation there is also a path in the burst ('NETWORK', 'NETWORK LAYER')
# For the gold relation there is also a path in the burst ('NETWORK', 'LINK LAYER')
# For the gold relation there is also a path in the burst ('NETWORK', 'INTERNET PROTOCOL')
# For the gold relation there is also a path in the burst ('NETWORK', 'INTERNET PROTOCOL ADDRESS')
# For the gold relation there is also a path in the burst ('NETWORK', 'NAME SERVER')
# For the gold relation there is also a path in the burst ('NETWORK', 'DOMAIN NAME SYSTEM')
# For the gold relation there is also a path in the burst ('NETWORK', 'DOMAIN')
# For the gold relation there is also a path in the burst ('NETWORK', 'DOMAIN NAME')
# For the gold relation there is also a path in the burst ('NETWORK', 'REGISTERED DOMAIN')
# For the gold relation there is also a path in the burst ('NETWORK', 'INTERNET PROTOCOL NETWORK')
# For the gold relation there is also a path in the burst ('NETWORK', 'CLIENT')
# For the gold relation there is also a path in the burst ('NETWORK', 'PEER-TO-PEER MODEL')
# For the gold relation there is also a path in the burst ('NETWORK', 'INSTANT MESSAGING')
# For the gold relation there is also a path in the burst ('NETWORK', 'HYPERTEXT TRANSFER PROTOCOL')
# For the gold relation there is also a path in the burst ('NETWORK', 'END USER')
# For the gold relation there is also a path in the burst ('NETWORK', 'SECURE SOCKET LAYER')
# For the gold relation there is also a path in the burst ('NETWORK', 'DENIAL OF SERVICE')
# For the gold relation there is also a path in the burst ('NETWORK', 'WORLD WIDE WEB')
# For the gold relation there is also a path in the burst ('NETWORK', 'BROWSER')
# For the gold relation there is also a path in the burst ('NETWORK', 'PROXY SERVER')
# For the gold relation there is also a path in the burst ('NETWORK', 'FILE SERVER')
# For the gold relation there is also a path in the burst ('NETWORK', 'PRINT SERVER')
# For the gold relation there is also a path in the burst ('NETWORK', 'REMOTE SERVER')
# For the gold relation there is also a path in the burst ('NETWORK', '1G')
# For the gold relation there is also a path in the burst ('NETWORK', 'SECOND GENERATION')
# For the gold relation there is also a path in the burst ('NETWORK', '3G')
# For the gold relation there is also a path in the burst ('NETWORK', 'CARRIER SENSE , MULTIPLE ACCESS WITH COLLISION DETECTION')
# For the gold relation there is also a path in the burst ('NETWORK', 'VOICE OVER INTERNET PROTOCOL')
# For the gold relation there is also a path in the burst ('NETWORK', 'TRANSMISSION CONTROL PROTOCOL/INTERNET PROTOCOL NETWORK')
# For the gold relation there is also a path in the burst ('NETWORK', 'NETWORK NEWS TRANSFER PROTOCOL')
# For the gold relation there is also a path in the burst ('NETWORK', 'FILE TRANSFER PROTOCOL')
# For the gold relation there is also a path in the burst ('NETWORK', 'TRADITIONAL TELEPHONE')
# For the gold relation there is also a path in the burst ('NETWORK', 'TIER-1 INTERNET SERVICE PROVIDER')
# For the gold relation there is also a path in the burst ('NETWORK', 'TIER-2 INTERNET SERVICE PROVIDER')
# For the gold relation there is also a path in the burst ('NETWORK', 'TIER-3 INTERNET SERVICE PROVIDER')
# For the gold relation there is also a path in the burst ('NETWORK', 'INTRANET')
# For the gold relation there is also a path in the burst ('NETWORK', 'ACCESS INTERNET SERVICE PROVIDER')
# For the gold relation there is also a path in the burst ('NETWORK', 'INTERNET2')
# For the gold relation there is also a path in the burst ('NETWORK', 'EMAIL')
# For the gold relation there is also a path in the burst ('NETWORK', 'TROJAN HORSE')
# For the gold relation there is also a path in the burst ('NETWORK', 'ENCRYPTION')
# For the gold relation there is also a path in the burst ('NETWORK', 'PRIVATE-KEY')
# For the gold relation there is also a path in the burst ('NETWORK', 'CLUSTER COMPUTE')
# For the gold relation there is also a path in the burst ('NETWORK', 'GRID COMPUTE')
# For the gold relation there is also a path in the burst ('NETWORK', 'CLOUD COMPUTING')
# For the gold relation there is also a path in the burst ('NETWORK', 'HUB')
# For the gold relation there is also a path in the burst ('NETWORK', 'SWITCH')
# For the gold relation there is also a path in the burst ('NETWORK', 'REPEATER')
# For the gold relation there is also a path in the burst ('NETWORK', 'BRIDGE')
# For the gold relation there is also a path in the burst ('NETWORK', 'ACCESS POINT')
# For the gold relation there is also a path in the burst ('NETWORK', 'HOT SPOT')
# For the gold relation there is also a path in the burst ('NETWORK', 'VIRUS')
# For the gold relation there is also a path in the burst ('SIMPLE MAIL TRANSFER PROTOCOL', 'REMOTE MAIL SERVER')
# For the gold relation there is also a path in the burst ('SIMPLE MAIL TRANSFER PROTOCOL', 'MAIL SERVER')
# For the gold relation there is also a path in the burst ('SIMPLE MAIL TRANSFER PROTOCOL', 'POST OFFICE PROTOCOL VERSION 3')
# For the gold relation there is also a path in the burst ('SIMPLE MAIL TRANSFER PROTOCOL', 'INTERNET MAIL ACCESS PROTOCOL')
# For the gold relation there is also a path in the burst ('MAIL SERVER', 'POST OFFICE PROTOCOL VERSION 3')
# For the gold relation there is also a path in the burst ('MAIL SERVER', 'INTERNET MAIL ACCESS PROTOCOL')
# For the gold relation there is also a path in the burst ('MAIL SERVER', 'SERVER-SIDE')
# For the gold relation there is also a path in the burst ('MAIL SERVER', 'REMOTE MAIL SERVER')
# For the gold relation there is also a path in the burst ('PHONE NETWORK', '4G')
# For the gold relation there is also a path in the burst ('UNIFORM RESOURCE LOCATOR', 'HYPERTEXT MARKUP LANGUAGE')
# For the gold relation there is also a path in the burst ('UNIFORM RESOURCE LOCATOR', 'SEARCH ENGINE')
# For the gold relation there is also a path in the burst ('UNIFORM RESOURCE LOCATOR', 'CLIENT-SIDE')
# For the gold relation there is also a path in the burst ('UNIFORM RESOURCE LOCATOR', 'TAG')
# For the gold relation there is also a path in the burst ('HYPERTEXT MARKUP LANGUAGE', 'SEARCH ENGINE')
# For the gold relation there is also a path in the burst ('HYPERTEXT MARKUP LANGUAGE', 'TAG')
# For the gold relation there is also a path in the burst ('HYPERTEXT MARKUP LANGUAGE', 'HEAD')
# For the gold relation there is also a path in the burst ('HYPERTEXT MARKUP LANGUAGE', 'CLIENT-SIDE')
# For the gold relation there is also a path in the burst ('SEARCH ENGINE', 'CLIENT-SIDE')
# For the gold relation there is also a path in the burst ('SERVER', 'SERVLETS')
# For the gold relation there is also a path in the burst ('SERVER', 'FILE SERVER')
# For the gold relation there is also a path in the burst ('SERVER', 'CONTENT DELIVERY NETWORK')
# For the gold relation there is also a path in the burst ('SERVER', 'NAME SERVER')
# For the gold relation there is also a path in the burst ('SERVER', 'PROXY SERVER')
# For the gold relation there is also a path in the burst ('SERVER', 'CLIENT/SERVER MODEL')
# For the gold relation there is also a path in the burst ('SERVER', 'PRINT SERVER')
# For the gold relation there is also a path in the burst ('SERVER', 'WEBSERVERS')
# For the gold relation there is also a path in the burst ('SERVER', 'MAIL SERVER')
# For the gold relation there is also a path in the burst ('SERVER', 'SERVER-SIDE')
# For the gold relation there is also a path in the burst ('SERVER', 'WEBSERVER')
# For the gold relation there is also a path in the burst ('SERVER', 'UNIFORM RESOURCE LOCATOR')
# For the gold relation there is also a path in the burst ('SERVER', 'REMOTE SERVER')
# For the gold relation there is also a path in the burst ('SERVER', 'DOMAIN NAME SYSTEM')
# For the gold relation there is also a path in the burst ('SERVER', 'INTERNET PROTOCOL ADDRESS')
# For the gold relation there is also a path in the burst ('SERVER', 'DOMAIN')
# For the gold relation there is also a path in the burst ('SERVER', 'DOMAIN NAME')
# For the gold relation there is also a path in the burst ('SERVER', 'INTERNET PROTOCOL NETWORK')
# For the gold relation there is also a path in the burst ('SERVER', '4G')
# For the gold relation there is also a path in the burst ('SERVER', 'HYPERTEXT TRANSFER PROTOCOL')
# For the gold relation there is also a path in the burst ('SERVER', 'END USER')
# For the gold relation there is also a path in the burst ('SERVER', 'INSTANT MESSAGING')
# For the gold relation there is also a path in the burst ('SERVER', 'SIMPLE MAIL TRANSFER PROTOCOL')
# For the gold relation there is also a path in the burst ('SERVER', 'REMOTE MAIL SERVER')
# For the gold relation there is also a path in the burst ('SERVER', 'PHP')
# For the gold relation there is also a path in the burst ('SERVER', 'CLIENT-SIDE')
# For the gold relation there is also a path in the burst ('SERVER', 'JAVASERVER PAGE')
# For the gold relation there is also a path in the burst ('SERVER', 'ACTIVE SERVER PAGE')
# For the gold relation there is also a path in the burst ('SERVER', 'DENIAL OF SERVICE')
# For the gold relation there is also a path in the burst ('SERVER', 'FIREWALL')
# For the gold relation there is also a path in the burst ('SERVER', 'AUDITING SOFTWARE')
# For the gold relation there is also a path in the burst ('SERVER', 'HYPERTEXT')
# For the gold relation there is also a path in the burst ('SERVER', 'HYPERTEXT DOCUMENT')
# For the gold relation there is also a path in the burst ('SERVER', 'HYPERTEXT MARKUP LANGUAGE')
# For the gold relation there is also a path in the burst ('SERVER', 'SEARCH ENGINE')
# For the gold relation there is also a path in the burst ('SERVER', 'TAG')
# For the gold relation there is also a path in the burst ('SERVER', 'BODY')
# For the gold relation there is also a path in the burst ('SERVER', 'WORLD WIDE WEB')
# For the gold relation there is also a path in the burst ('SERVER', 'BROWSER')
# For the gold relation there is also a path in the burst ('SOFTWARE', 'SECURE SHELL')
# For the gold relation there is also a path in the burst ('SOFTWARE', 'ENCRYPTION')
# For the gold relation there is also a path in the burst ('SOFTWARE', 'VIRUS')
# For the gold relation there is also a path in the burst ('SOFTWARE', 'WORM')
# For the gold relation there is also a path in the burst ('SOFTWARE', 'TROJAN HORSE')
# For the gold relation there is also a path in the burst ('SOFTWARE', 'SPYWARE')
# For the gold relation there is also a path in the burst ('SOFTWARE', 'DENIAL OF SERVICE')
# For the gold relation there is also a path in the burst ('SOFTWARE', 'INTERNET SOFTWARE')
# For the gold relation there is also a path in the burst ('SOFTWARE', 'AUDITING SOFTWARE')
# For the gold relation there is also a path in the burst ('SOFTWARE', 'ANTIVIRUS SOFTWARE')
# For the gold relation there is also a path in the burst ('SOFTWARE', 'NETWORK SOFTWARE')
# For the gold relation there is also a path in the burst ('SOFTWARE', 'PROXY SERVER')
# For the gold relation there is also a path in the burst ('SOFTWARE', 'WEBSERVERS')
# For the gold relation there is also a path in the burst ('SOFTWARE', 'DISTRIBUTED SYSTEM')
# For the gold relation there is also a path in the burst ('SOFTWARE', 'BROWSER')
# For the gold relation there is also a path in the burst ('SOFTWARE', 'MALICIOUS SOFTWARE')
# For the gold relation there is also a path in the burst ('SOFTWARE', 'APPLICATION LAYER')
# For the gold relation there is also a path in the burst ('SOFTWARE', 'FIREWALL')
# For the gold relation there is also a path in the burst ('SOFTWARE', 'NETWORK LAYER')
# For the gold relation there is also a path in the burst ('SOFTWARE', 'LINK LAYER')
# For the gold relation there is also a path in the burst ('SOFTWARE', 'PORT NUMBER')
# For the gold relation there is also a path in the burst ('SOFTWARE', 'TRANSPORT LAYER')
# For the gold relation there is also a path in the burst ('SOFTWARE', 'FORWARDING TABLE')
# For the gold relation there is also a path in the burst ('SOFTWARE', 'DOMAIN')
# For the gold relation there is also a path in the burst ('SOFTWARE', 'PHISHING')
# For the gold relation there is also a path in the burst ('SOFTWARE', 'INTERNET')
# For the gold relation there is also a path in the burst ('SOFTWARE', 'PROTOCOL')
# For the gold relation there is also a path in the burst ('SOFTWARE', 'HYPERTEXT TRANSFER PROTOCOL')
# For the gold relation there is also a path in the burst ('SOFTWARE', 'SIMPLE MAIL TRANSFER PROTOCOL')
# For the gold relation there is also a path in the burst ('SOFTWARE', 'REMOTE MAIL SERVER')
# For the gold relation there is also a path in the burst ('SOFTWARE', 'MAIL SERVER')
# For the gold relation there is also a path in the burst ('SOFTWARE', 'POST OFFICE PROTOCOL VERSION 3')
# For the gold relation there is also a path in the burst ('SOFTWARE', 'INTERNET MAIL ACCESS PROTOCOL')
# For the gold relation there is also a path in the burst ('SOFTWARE', 'VOICE OVER INTERNET PROTOCOL')
# For the gold relation there is also a path in the burst ('SOFTWARE', 'TRANSMISSION CONTROL PROTOCOL/INTERNET PROTOCOL NETWORK')
# For the gold relation there is also a path in the burst ('SOFTWARE', 'FILE TRANSFER PROTOCOL')
# For the gold relation there is also a path in the burst ('SOFTWARE', 'WORLD WIDE WEB')
# For the gold relation there is also a path in the burst ('SOFTWARE', 'HYPERTEXT')
# For the gold relation there is also a path in the burst ('SOFTWARE', 'HYPERTEXT DOCUMENT')
# For the gold relation there is also a path in the burst ('SOFTWARE', 'BODY')
# For the gold relation there is also a path in the burst ('SOFTWARE', 'WEBSERVER')
# For the gold relation there is also a path in the burst ('SOFTWARE', 'TRADITIONAL TELEPHONE')
# For the gold relation there is also a path in the burst ('SOFTWARE', 'INTRANET')
# For the gold relation there is also a path in the burst ('SOFTWARE', 'GATEWAY')
# For the gold relation there is also a path in the burst ('SOFTWARE', 'INTERNET INFRASTRUCTURE')
# For the gold relation there is also a path in the burst ('SOFTWARE', 'EMAIL')
# For the gold relation there is also a path in the burst ('SOFTWARE', 'ROUTER')
# For the gold relation there is also a path in the burst ('SOFTWARE', 'CLUSTER COMPUTE')
# For the gold relation there is also a path in the burst ('SOFTWARE', 'GRID COMPUTE')
# For the gold relation there is also a path in the burst ('SOFTWARE', 'CLOUD COMPUTING')
# For the gold relation there is also a path in the burst ('SECURE SHELL', 'TRANSPORT LAYER')
# For the gold relation there is also a path in the burst ('TRANSMISSION CONTROL PROTOCOL', 'USER DATAGRAM PROTOCOL')
# For the gold relation there is also a path in the burst ('FORWARDING TABLE', 'USER DATAGRAM PROTOCOL')
# For the gold relation there is also a path in the burst ('FORWARDING TABLE', 'PORT NUMBER')
# For the gold relation there is also a path in the burst ('FORWARDING TABLE', 'TRANSMISSION CONTROL PROTOCOL')
# For the gold relation there is also a path in the burst ('FORWARDING TABLE', 'HOP COUNT')
# For the gold relation there is also a path in the burst ('INTERNET PROTOCOL NETWORK', 'HOP COUNT')
# For the gold relation there is also a path in the burst ('COMPUTER SYSTEM', 'MALICIOUS SOFTWARE')
# For the gold relation there is also a path in the burst ('COMPUTER SYSTEM', 'TROJAN HORSE')
# For the gold relation there is also a path in the burst ('COMPUTER SYSTEM', 'VIRUS')
# For the gold relation there is also a path in the burst ('COMPUTER SYSTEM', 'WORM')
# For the gold relation there is also a path in the burst ('COMPUTER SYSTEM', 'SPYWARE')
# For the gold relation there is also a path in the burst ('COMPUTER SYSTEM', 'PHISHING')
# For the gold relation there is also a path in the burst ('MALICIOUS SOFTWARE', 'VIRUS')
# For the gold relation there is also a path in the burst ('MALICIOUS SOFTWARE', 'WORM')
# For the gold relation there is also a path in the burst ('MALICIOUS SOFTWARE', 'TROJAN HORSE')
# For the gold relation there is also a path in the burst ('MALICIOUS SOFTWARE', 'SPYWARE')
# For the gold relation there is also a path in the burst ('MALICIOUS SOFTWARE', 'PHISHING')
# For the gold relation there is also a path in the burst ('ENCRYPTION', 'PRIVATE-KEY')
# For the gold relation there is also a path in the burst ('ENCRYPTION', 'PUBLIC-KEY ENCRYPTION')
# For the gold relation there is also a path in the burst ('ENCRYPTION', 'DIGITAL SIGNATURE')
# For the gold relation there is also a path in the burst ('ENCRYPTION', 'PUBLIC-KEY')
# For the gold relation there is also a path in the burst ('ENCRYPTION', 'CERTIFICATE')
# For the gold relation there is also a path in the burst ('ENCRYPTION', 'CERTIFICATE AUTHORITY')
# For the gold relation there is also a path in the burst ('PRIVATE-KEY', 'DIGITAL SIGNATURE')
# For the gold relation there is also a path in the burst ('PUBLIC-KEY', 'CERTIFICATE')
# For the gold relation there is also a path in the burst ('PUBLIC-KEY', 'CERTIFICATE AUTHORITY')
# For the gold relation there is also a path in the burst ('BIT PATTERN', 'NAME SERVER')
# For the gold relation there is also a path in the burst ('BIT PATTERN', 'DOMAIN NAME SYSTEM')
# For the gold relation there is also a path in the burst ('BIT PATTERN', 'DOMAIN')
# For the gold relation there is also a path in the burst ('BIT PATTERN', 'SUBDOMAINS')
# For the gold relation there is also a path in the burst ('BIT PATTERN', 'MNEMONIC DOMAIN NAME')
# For the gold relation there is also a path in the burst ('BIT PATTERN', 'TOP-LEVEL DOMAINS')
# For the gold relation there is also a path in the burst ('BIT PATTERN', 'DOMAIN NAME')
# For the gold relation there is also a path in the burst ('WEBSERVER', 'CLIENT-SIDE')
# For the gold relation there is also a path in the burst ('WEBSERVER', 'SERVER-SIDE')
# For the gold relation there is also a path in the burst ('WEBSERVER', 'JAVASERVER PAGE')
# For the gold relation there is also a path in the burst ('WEBSERVER', 'ACTIVE SERVER PAGE')
# For the gold relation there is also a path in the burst ('WEBSERVER', 'SERVLETS')
# For the gold relation there is also a path in the burst ('WEBSERVER', 'PHP')
# For the gold relation there is also a path in the burst ('WEBSERVER', 'UNIFORM RESOURCE LOCATOR')
# For the gold relation there is also a path in the burst ('WEBSERVER', 'HYPERTEXT MARKUP LANGUAGE')
# For the gold relation there is also a path in the burst ('WEBSERVER', 'SEARCH ENGINE')
# For the gold relation there is also a path in the burst ('WEBSERVER', 'TAG')
# For the gold relation there is also a path in the burst ('COMPUTER', 'SOFTWARE')
# For the gold relation there is also a path in the burst ('COMPUTER', 'COMPUTER SYSTEM')
# For the gold relation there is also a path in the burst ('COMPUTER', 'NETWORK')
# For the gold relation there is also a path in the burst ('COMPUTER', 'DENIAL OF SERVICE')
# For the gold relation there is also a path in the burst ('COMPUTER', 'DISTRIBUTED SYSTEM')
# For the gold relation there is also a path in the burst ('COMPUTER', 'ADDRESSING SYSTEM')
# For the gold relation there is also a path in the burst ('COMPUTER', 'MASS STORAGE')
# For the gold relation there is also a path in the burst ('COMPUTER', 'VIRUS')
# For the gold relation there is also a path in the burst ('COMPUTER', 'TROJAN HORSE')
# For the gold relation there is also a path in the burst ('COMPUTER', 'SPYWARE')
# For the gold relation there is also a path in the burst ('COMPUTER', 'INTERNET PROTOCOL')
# For the gold relation there is also a path in the burst ('COMPUTER', 'INTERNET PROTOCOL ADDRESS')
# For the gold relation there is also a path in the burst ('COMPUTER', 'DIGITAL SIGNATURE')
# For the gold relation there is also a path in the burst ('COMPUTER', 'NAME SERVER')
# For the gold relation there is also a path in the burst ('COMPUTER', 'DOMAIN NAME SYSTEM')
# For the gold relation there is also a path in the burst ('COMPUTER', 'DOMAIN')
# For the gold relation there is also a path in the burst ('COMPUTER', 'DOMAIN NAME')
# For the gold relation there is also a path in the burst ('COMPUTER', 'REGISTERED DOMAIN')
# For the gold relation there is also a path in the burst ('COMPUTER', 'ENCRYPTION')
# For the gold relation there is also a path in the burst ('COMPUTER', 'PRIVATE-KEY')
# For the gold relation there is also a path in the burst ('COMPUTER', 'PROXY SERVER')
# For the gold relation there is also a path in the burst ('COMPUTER', 'ANTIVIRUS SOFTWARE')
# For the gold relation there is also a path in the burst ('COMPUTER', 'WORM')
# For the gold relation there is also a path in the burst ('COMPUTER', 'PHISHING')
# For the gold relation there is also a path in the burst ('COMPUTER', 'FIREWALL')
# For the gold relation there is also a path in the burst ('COMPUTER', 'AUDITING SOFTWARE')
# For the gold relation there is also a path in the burst ('COMPUTER', 'NETWORK SOFTWARE')
# For the gold relation there is also a path in the burst ('COMPUTER', 'INTERNET')
# For the gold relation there is also a path in the burst ('COMPUTER', 'PROTOCOL')
# For the gold relation there is also a path in the burst ('COMPUTER', 'CARRIER SENSE , MULTIPLE ACCESS WITH COLLISION DETECTION')
# For the gold relation there is also a path in the burst ('COMPUTER', 'HYPERTEXT TRANSFER PROTOCOL')
# For the gold relation there is also a path in the burst ('COMPUTER', 'END USER')
# For the gold relation there is also a path in the burst ('COMPUTER', 'INSTANT MESSAGING')
# For the gold relation there is also a path in the burst ('COMPUTER', 'SIMPLE MAIL TRANSFER PROTOCOL')
# For the gold relation there is also a path in the burst ('COMPUTER', 'MAIL SERVER')
# For the gold relation there is also a path in the burst ('COMPUTER', 'POST OFFICE PROTOCOL VERSION 3')
# For the gold relation there is also a path in the burst ('COMPUTER', 'INTERNET MAIL ACCESS PROTOCOL')
# For the gold relation there is also a path in the burst ('COMPUTER', 'VOICE OVER INTERNET PROTOCOL')
# For the gold relation there is also a path in the burst ('COMPUTER', 'NETWORK NEWS TRANSFER PROTOCOL')
# For the gold relation there is also a path in the burst ('COMPUTER', 'FILE TRANSFER PROTOCOL')
# For the gold relation there is also a path in the burst ('COMPUTER', 'WORLD WIDE WEB')
# For the gold relation there is also a path in the burst ('COMPUTER', 'HYPERTEXT')
# For the gold relation there is also a path in the burst ('COMPUTER', 'HYPERTEXT DOCUMENT')
# For the gold relation there is also a path in the burst ('COMPUTER', 'UNIFORM RESOURCE LOCATOR')
# For the gold relation there is also a path in the burst ('COMPUTER', 'HYPERTEXT MARKUP LANGUAGE')
# For the gold relation there is also a path in the burst ('COMPUTER', 'SEARCH ENGINE')
# For the gold relation there is also a path in the burst ('COMPUTER', 'TAG')
# For the gold relation there is also a path in the burst ('COMPUTER', 'HEAD')
# For the gold relation there is also a path in the burst ('COMPUTER', 'BODY')
# For the gold relation there is also a path in the burst ('COMPUTER', 'WEBSERVER')
# For the gold relation there is also a path in the burst ('COMPUTER', 'WEBSERVERS')
# For the gold relation there is also a path in the burst ('COMPUTER', 'BROWSER')
# For the gold relation there is also a path in the burst ('COMPUTER', 'TRADITIONAL TELEPHONE')
# For the gold relation there is also a path in the burst ('COMPUTER', 'INTRANET')
# For the gold relation there is also a path in the burst ('COMPUTER', 'GATEWAY')
# For the gold relation there is also a path in the burst ('COMPUTER', 'INTERNET SERVICE PROVIDER')
# For the gold relation there is also a path in the burst ('COMPUTER', 'ACCESS INTERNET SERVICE PROVIDER')
# For the gold relation there is also a path in the burst ('COMPUTER', 'EMAIL')
# For the gold relation there is also a path in the burst ('COMPUTER', 'ROUTER')
# For the gold relation there is also a path in the burst ('COMPUTER', 'CLUSTER COMPUTE')
# For the gold relation there is also a path in the burst ('COMPUTER', 'GRID COMPUTE')
# For the gold relation there is also a path in the burst ('COMPUTER', 'CLOUD COMPUTING')
# For the gold relation there is also a path in the burst ('COMPUTER', 'MALICIOUS SOFTWARE')
# For the gold relation there is also a path in the burst ('COMPUTER', 'INTERPROCESS COMMUNICATION')
# For the gold relation there is also a path in the burst ('COMPUTER', 'CLIENT/SERVER MODEL')
# For the gold relation there is also a path in the burst ('COMPUTER', 'CLIENT')
# For the gold relation there is also a path in the burst ('COMPUTER', 'PEER-TO-PEER MODEL')
# For the gold relation there is also a path in the burst ('COMPUTER', 'SERVER')
# For the gold relation there is also a path in the burst ('COMPUTER', 'PRINT SERVER')
# For the gold relation there is also a path in the burst ('COMPUTER', 'OPEN NETWORK')
# For the gold relation there is also a path in the burst ('COMPUTER', 'PERSONAL AREA NETWORK')
# For the gold relation there is also a path in the burst ('COMPUTER', 'LOCAL AREA NETWORK')
# For the gold relation there is also a path in the burst ('COMPUTER', 'METROPOLITAN AREA NETWORK')
# For the gold relation there is also a path in the burst ('COMPUTER', 'WIDE AREA NETWORK')
# For the gold relation there is also a path in the burst ('COMPUTER', 'BUS')
# For the gold relation there is also a path in the burst ('COMPUTER', 'HUB')
# For the gold relation there is also a path in the burst ('COMPUTER', 'STAR')
# For the gold relation there is also a path in the burst ('COMPUTER', 'WIRELESS NETWORK')
# For the gold relation there is also a path in the burst ('COMPUTER', 'ACCESS POINT')
# For the gold relation there is also a path in the burst ('COMPUTER', 'WIFI NETWORK')
# For the gold relation there is also a path in the burst ('COMPUTER', 'MAGNETIC DISK')
# For the gold relation there is also a path in the burst ('INTERPROCESS COMMUNICATION', 'CLIENT/SERVER MODEL')
# For the gold relation there is also a path in the burst ('INTERPROCESS COMMUNICATION', 'CLIENT')
# For the gold relation there is also a path in the burst ('INTERPROCESS COMMUNICATION', 'SERVER')
# For the gold relation there is also a path in the burst ('INTERPROCESS COMMUNICATION', 'PRINT SERVER')
# For the gold relation there is also a path in the burst ('DOMAIN', 'SUBDOMAINS')
# For the gold relation there is also a path in the burst ('DOMAIN', 'MNEMONIC DOMAIN NAME')
# For the gold relation there is also a path in the burst ('DOMAIN', 'TOP-LEVEL DOMAINS')
# For the gold relation there is also a path in the burst ('DOMAIN', 'DOMAIN NAME')
# For the gold relation there is also a path in the burst ('DOMAIN', 'REGISTERED DOMAIN')
# For the gold relation there is also a path in the burst ('DOMAIN', 'NAME SERVER')
# For the gold relation there is also a path in the burst ('DOMAIN', 'DOMAIN NAME SYSTEM')
# For the gold relation there is also a path in the burst ('WORLD WIDE WEB', 'HYPERTEXT')
# For the gold relation there is also a path in the burst ('WORLD WIDE WEB', 'HYPERTEXT DOCUMENT')
# For the gold relation there is also a path in the burst ('WORLD WIDE WEB', 'HYPERTEXT MARKUP LANGUAGE')
# For the gold relation there is also a path in the burst ('WORLD WIDE WEB', 'TAG')
# For the gold relation there is also a path in the burst ('WORLD WIDE WEB', 'HEAD')
# For the gold relation there is also a path in the burst ('WORLD WIDE WEB', 'WEBSERVERS')
# For the gold relation there is also a path in the burst ('HYPERTEXT', 'HYPERTEXT DOCUMENT')
# For the gold relation there is also a path in the burst ('HYPERTEXT', 'WEBSERVERS')
# For the gold relation there is also a path in the burst ('HYPERTEXT', 'HYPERTEXT MARKUP LANGUAGE')
# For the gold relation there is also a path in the burst ('HYPERTEXT', 'TAG')
# For the gold relation there is also a path in the burst ('HYPERTEXT', 'HEAD')
# For the gold relation there is also a path in the burst ('HYPERTEXT', 'WEBSERVER')
# For the gold relation there is also a path in the burst ('BROWSER', 'UNIFORM RESOURCE LOCATOR')
# For the gold relation there is also a path in the burst ('BROWSER', 'WEBSERVER')
# For the gold relation there is also a path in the burst ('BROWSER', 'HYPERTEXT TRANSFER PROTOCOL')
# For the gold relation there is also a path in the burst ('BROWSER', 'CLIENT-SIDE')
# For the gold relation there is also a path in the burst ('BROWSER', 'HYPERTEXT')
# For the gold relation there is also a path in the burst ('BROWSER', 'HYPERTEXT DOCUMENT')
# For the gold relation there is also a path in the burst ('BROWSER', 'HYPERTEXT MARKUP LANGUAGE')
# For the gold relation there is also a path in the burst ('BROWSER', 'SEARCH ENGINE')
# For the gold relation there is also a path in the burst ('BROWSER', 'TAG')
# For the gold relation there is also a path in the burst ('BROWSER', 'HEAD')
# For the gold relation there is also a path in the burst ('BROWSER', 'BODY')
# For the gold relation there is also a path in the burst ('BROWSER', 'SERVER-SIDE')
# For the gold relation there is also a path in the burst ('BROWSER', 'SERVLETS')
# For the gold relation there is also a path in the burst ('BROWSER', 'END USER')
# For the gold relation there is also a path in the burst ('BROWSER', 'INSTANT MESSAGING')
# For the gold relation there is also a path in the burst ('BROWSER', 'WORLD WIDE WEB')
# For the gold relation there is also a path in the burst ('BROWSER', 'WEBSERVERS')
# For the gold relation there is also a path in the burst ('TAG', 'HEAD')
# For the gold relation there is also a path in the burst ('TAG', 'SEARCH ENGINE')
# For the gold relation there is also a path in the burst ('TAG', 'CLIENT-SIDE')
# For the gold relation there is also a path in the burst ('TAG', 'EXTENSIBLE MARKUP LANGUAGE')
# For the gold relation there is also a path in the burst ('EXTENSIBLE MARKUP LANGUAGE', 'SEARCH ENGINE')
# For the gold relation there is also a path in the burst ('SERVLET', 'JAVASERVER PAGE')
# For the gold relation there is also a path in the burst ('SERVLET', 'ACTIVE SERVER PAGE')
# For the gold relation there is also a path in the burst ('JAVASERVER PAGE', 'ACTIVE SERVER PAGE')
# For the gold relation there is also a path in the burst ('TRANSPORT LAYER', 'PORT NUMBER')
# For the gold relation there is also a path in the burst ('TRANSPORT LAYER', 'USER DATAGRAM PROTOCOL')
# For the gold relation there is also a path in the burst ('TRANSPORT LAYER', 'TRANSMISSION CONTROL PROTOCOL')
# For the gold relation there is also a path in the burst ('TRANSPORT LAYER', 'FORWARDING TABLE')
# For the gold relation there is also a path in the burst ('VIRUS', 'PROXY SERVER')
# For the gold relation there is also a path in the burst ('VIRUS', 'ANTIVIRUS SOFTWARE')
# For the gold relation there is also a path in the burst ('SPYWARE', 'PHISHING')
# For the gold relation there is also a path in the burst ('DENIAL OF SERVICE', 'FIREWALL')
# For the gold relation there is also a path in the burst ('SERVER-SIDE', 'SERVLETS')
# For the gold relation there is also a path in the burst ('OPEN NETWORK', 'INTERNET')
# For the gold relation there is also a path in the burst ('WIRELESS NETWORK', 'ACCESS POINT')
# For the gold relation there is also a path in the burst ('WIRELESS NETWORK', 'COLLISION AVOIDANCE')
# For the gold relation there is also a path in the burst ('WIRELESS NETWORK', 'HIDDEN TERMINAL PROBLEM')
# For the gold relation there is also a path in the burst ('ACCESS POINT', 'HIDDEN TERMINAL PROBLEM')
# For the gold relation there is also a path in the burst ('ACCESS POINT', 'HOT SPOT')
# For the gold relation there is also a path in the burst ('ACCESS POINT', 'GATEWAY')
# For the gold relation there is also a path in the burst ('BUS', 'HUB')
# For the gold relation there is also a path in the burst ('BUS', 'SWITCH')
# For the gold relation there is also a path in the burst ('BUS', 'ETHERNET NETWORK')
# For the gold relation there is also a path in the burst ('BUS', 'REPEATER')
# For the gold relation there is also a path in the burst ('BUS', 'BRIDGE')
# For the gold relation there is also a path in the burst ('BUS', 'CARRIER SENSE , MULTIPLE ACCESS WITH COLLISION DETECTION')
# For the gold relation there is also a path in the burst ('BUS', 'ROUTER')
# For the gold relation there is also a path in the burst ('ROUTER', 'FORWARDING TABLE')
# For the gold relation there is also a path in the burst ('ROUTER', 'TIER-2 INTERNET SERVICE PROVIDER')
# For the gold relation there is also a path in the burst ('ROUTER', 'GATEWAY')
# For the gold relation there is also a path in the burst ('ROUTER', 'HOP COUNT')
# For the gold relation there is also a path in the burst ('ROUTER', 'NETWORK LAYER')
# For the gold relation there is also a path in the burst ('ROUTER', 'LINK LAYER')
# For the gold relation there is also a path in the burst ('ROUTER', 'USER DATAGRAM PROTOCOL')
# For the gold relation there is also a path in the burst ('ROUTER', 'APPLICATION LAYER')
# For the gold relation there is also a path in the burst ('ROUTER', 'INTERNET PROTOCOL')
# For the gold relation there is also a path in the burst ('ROUTER', 'INTERNET PROTOCOL NETWORK')
# For the gold relation there is also a path in the burst ('ROUTER', 'TRANSPORT LAYER')
# For the gold relation there is also a path in the burst ('ROUTER', 'TIER-3 INTERNET SERVICE PROVIDER')
# For the gold relation there is also a path in the burst ('ADDRESSING SYSTEM', 'INTERNET PROTOCOL ADDRESS')
# For the gold relation there is also a path in the burst ('ADDRESSING SYSTEM', 'DOMAIN')
# For the gold relation there is also a path in the burst ('ADDRESSING SYSTEM', 'BIT PATTERN')
# For the gold relation there is also a path in the burst ('ADDRESSING SYSTEM', 'INTERNET PROTOCOL')
# For the gold relation there is also a path in the burst ('ADDRESSING SYSTEM', 'MNEMONIC DOMAIN NAME')
# For the gold relation there is also a path in the burst ('ADDRESSING SYSTEM', 'DOMAIN NAME')
# For the gold relation there is also a path in the burst ('GATEWAY', 'FIREWALL')
# For the gold relation there is also a path in the burst ('INTERNET SERVICE PROVIDER', 'INTERNET PROTOCOL ADDRESS')
# For the gold relation there is also a path in the burst ('INTERNET SERVICE PROVIDER', 'TIER-1 INTERNET SERVICE PROVIDER')
# For the gold relation there is also a path in the burst ('INTERNET SERVICE PROVIDER', 'TIER-2 INTERNET SERVICE PROVIDER')
# For the gold relation there is also a path in the burst ('INTERNET SERVICE PROVIDER', 'ACCESS INTERNET SERVICE PROVIDER')
# For the gold relation there is also a path in the burst ('INTERNET SERVICE PROVIDER', 'BIT PATTERN')
# For the gold relation there is also a path in the burst ('INTERNET SERVICE PROVIDER', 'NAME SERVER')
# For the gold relation there is also a path in the burst ('INTERNET SERVICE PROVIDER', 'DOMAIN NAME SYSTEM')
# For the gold relation there is also a path in the burst ('INTERNET SERVICE PROVIDER', 'INTERNET PROTOCOL')
# For the gold relation there is also a path in the burst ('INTERNET SERVICE PROVIDER', 'DOMAIN')
# For the gold relation there is also a path in the burst ('INTERNET SERVICE PROVIDER', 'SUBDOMAINS')
# For the gold relation there is also a path in the burst ('INTERNET SERVICE PROVIDER', 'MNEMONIC DOMAIN NAME')
# For the gold relation there is also a path in the burst ('INTERNET SERVICE PROVIDER', 'TOP-LEVEL DOMAINS')
# For the gold relation there is also a path in the burst ('INTERNET SERVICE PROVIDER', 'DOMAIN NAME')
# For the gold relation there is also a path in the burst ('INTERNET SERVICE PROVIDER', 'REGISTERED DOMAIN')
# For the gold relation there is also a path in the burst ('INTERNET SERVICE PROVIDER', 'TIER-3 INTERNET SERVICE PROVIDER')
# For the gold relation there is also a path in the burst ('INTERNET SERVICE PROVIDER', 'END SYSTEM')
# For the gold relation there is also a path in the burst ('INTERNET SERVICE PROVIDER', 'INTRANET')
# For the gold relation there is also a path in the burst ('ACCESS INTERNET SERVICE PROVIDER', 'END SYSTEM')
# For the gold relation there is also a path in the burst ('ACCESS INTERNET SERVICE PROVIDER', 'INTRANET')
# For the gold relation there is also a path in the burst ('EMAIL', 'BODY')
# For the gold relation there is also a path in the burst ('EMAIL', 'SIMPLE MAIL TRANSFER PROTOCOL')
# For the gold relation there is also a path in the burst ('EMAIL', 'TROJAN HORSE')
# For the gold relation there is also a path in the burst ('EMAIL', 'PHISHING')
# For the gold relation there is also a path in the burst ('EMAIL', 'FIREWALL')
# For the gold relation there is also a path in the burst ('EMAIL', 'MAIL SERVER')
# For the gold relation there is also a path in the burst ('EMAIL', 'POST OFFICE PROTOCOL VERSION 3')
# For the gold relation there is also a path in the burst ('EMAIL', 'INTERNET MAIL ACCESS PROTOCOL')
# For the gold relation there is also a path in the burst ('EMAIL', 'REMOTE MAIL SERVER')
# For the gold relation there is also a path in the burst ('HYPERTEXT DOCUMENT', 'UNIFORM RESOURCE LOCATOR')
# For the gold relation there is also a path in the burst ('HYPERTEXT DOCUMENT', 'WEBSERVER')
# For the gold relation there is also a path in the burst ('HYPERTEXT DOCUMENT', 'TAG')
# For the gold relation there is also a path in the burst ('HYPERTEXT DOCUMENT', 'HYPERTEXT MARKUP LANGUAGE')
# For the gold relation there is also a path in the burst ('HYPERTEXT DOCUMENT', 'WEBSERVERS')
# For the gold relation there is also a path in the burst ('INTERNET SOFTWARE', 'APPLICATION LAYER')
# For the gold relation there is also a path in the burst ('INTERNET SOFTWARE', 'NETWORK LAYER')
# For the gold relation there is also a path in the burst ('INTERNET SOFTWARE', 'LINK LAYER')
# For the gold relation there is also a path in the burst ('CERTIFICATE AUTHORITY', 'CERTIFICATE')
# For the gold relation there is also a path in the burst ('PERSONAL AREA NETWORK', 'LOCAL AREA NETWORK')
# For the gold relation there is also a path in the burst ('LOCAL AREA NETWORK', 'INTERNET')
# For the gold relation there is also a path in the burst ('LOCAL AREA NETWORK', 'TIER-1 INTERNET SERVICE PROVIDER')
# For the gold relation there is also a path in the burst ('LOCAL AREA NETWORK', 'TIER-2 INTERNET SERVICE PROVIDER')
# For the gold relation there is also a path in the burst ('LOCAL AREA NETWORK', 'TIER-3 INTERNET SERVICE PROVIDER')
# For the gold relation there is also a path in the burst ('LOCAL AREA NETWORK', 'INTRANET')
# For the gold relation there is also a path in the burst ('LOCAL AREA NETWORK', 'INTERNET SERVICE PROVIDER')
# For the gold relation there is also a path in the burst ('LOCAL AREA NETWORK', 'ACCESS INTERNET SERVICE PROVIDER')
# For the gold relation there is also a path in the burst ('LOCAL AREA NETWORK', 'END SYSTEM')
# For the gold relation there is also a path in the burst ('LOCAL AREA NETWORK', 'INTERNET2')
# For the gold relation there is also a path in the burst ('LOCAL AREA NETWORK', 'ROUTER')
# For the gold relation there is also a path in the burst ('METROPOLITAN AREA NETWORK', 'INTERNET')
# For the gold relation there is also a path in the burst ('METROPOLITAN AREA NETWORK', 'TIER-1 INTERNET SERVICE PROVIDER')
# For the gold relation there is also a path in the burst ('METROPOLITAN AREA NETWORK', 'TIER-2 INTERNET SERVICE PROVIDER')
# For the gold relation there is also a path in the burst ('METROPOLITAN AREA NETWORK', 'TIER-3 INTERNET SERVICE PROVIDER')
# For the gold relation there is also a path in the burst ('METROPOLITAN AREA NETWORK', 'INTRANET')
# For the gold relation there is also a path in the burst ('METROPOLITAN AREA NETWORK', 'INTERNET SERVICE PROVIDER')
# For the gold relation there is also a path in the burst ('METROPOLITAN AREA NETWORK', 'ACCESS INTERNET SERVICE PROVIDER')
# For the gold relation there is also a path in the burst ('METROPOLITAN AREA NETWORK', 'END SYSTEM')
# For the gold relation there is also a path in the burst ('METROPOLITAN AREA NETWORK', 'INTERNET2')
# For the gold relation there is also a path in the burst ('METROPOLITAN AREA NETWORK', 'ROUTER')
# For the gold relation there is also a path in the burst ('WIDE AREA NETWORK', 'INTERNET')
# For the gold relation there is also a path in the burst ('WIDE AREA NETWORK', 'TIER-1 INTERNET SERVICE PROVIDER')
# For the gold relation there is also a path in the burst ('WIDE AREA NETWORK', 'TIER-2 INTERNET SERVICE PROVIDER')
# For the gold relation there is also a path in the burst ('WIDE AREA NETWORK', 'TIER-3 INTERNET SERVICE PROVIDER')
# For the gold relation there is also a path in the burst ('WIDE AREA NETWORK', 'INTRANET')
# For the gold relation there is also a path in the burst ('WIDE AREA NETWORK', 'INTERNET SERVICE PROVIDER')
# For the gold relation there is also a path in the burst ('WIDE AREA NETWORK', 'ACCESS INTERNET SERVICE PROVIDER')
# For the gold relation there is also a path in the burst ('WIDE AREA NETWORK', 'END SYSTEM')
# For the gold relation there is also a path in the burst ('WIDE AREA NETWORK', 'INTERNET2')
# For the gold relation there is also a path in the burst ('WIDE AREA NETWORK', 'ROUTER')
# For the gold relation there is also a path in the burst ('STAR', 'WIRELESS NETWORK')
# For the gold relation there is also a path in the burst ('REPEATER', 'BRIDGE')
# For the gold relation there is also a path in the burst ('REPEATER', 'SWITCH')
# For the gold relation there is also a path in the burst ('BRIDGE', 'SWITCH')
# For the gold relation there is also a path in the burst ('DOMAIN NAME', 'SUBDOMAINS')
# For the gold relation there is also a path in the burst ('DOMAIN NAME', 'NAME SERVER')
# For the gold relation there is also a path in the burst ('DOMAIN NAME', 'DOMAIN NAME SYSTEM')
# For the gold relation there is also a path in the burst ('DOMAIN NAME', 'TOP-LEVEL DOMAINS')
# For the gold relation there is also a path in the burst ('DOMAIN NAME', 'REGISTERED DOMAIN')
# For the gold relation there is also a path in the burst ('NAME SERVER', 'DOMAIN NAME SYSTEM')
# For the gold relation there is also a path in the burst ('NAME SERVER', 'REGISTERED DOMAIN')
# For the gold relation there is also a path in the burst ('APPLICATION LAYER', 'NETWORK LAYER')
# For the gold relation there is also a path in the burst ('APPLICATION LAYER', 'PORT NUMBER')
# For the gold relation there is also a path in the burst ('APPLICATION LAYER', 'TRANSPORT LAYER')
# For the gold relation there is also a path in the burst ('APPLICATION LAYER', 'LINK LAYER')
# For the gold relation there is also a path in the burst ('APPLICATION LAYER', 'USER DATAGRAM PROTOCOL')
# For the gold relation there is also a path in the burst ('APPLICATION LAYER', 'TRANSMISSION CONTROL PROTOCOL')
# For the gold relation there is also a path in the burst ('APPLICATION LAYER', 'FORWARDING TABLE')
# For the gold relation there is also a path in the burst ('NETWORK LAYER', 'LINK LAYER')
# For the gold relation there is also a path in the burst ('NETWORK LAYER', 'USER DATAGRAM PROTOCOL')
# For the gold relation there is also a path in the burst ('NETWORK LAYER', 'PORT NUMBER')
# For the gold relation there is also a path in the burst ('NETWORK LAYER', 'TRANSPORT LAYER')
# For the gold relation there is also a path in the burst ('NETWORK LAYER', 'TRANSMISSION CONTROL PROTOCOL')
# For the gold relation there is also a path in the burst ('NETWORK LAYER', 'FORWARDING TABLE')
# For the gold relation there is also a path in the burst ('NETWORK LAYER', 'HOP COUNT')
# For the gold relation there is also a path in the burst ('PUBLIC-KEY ENCRYPTION', 'PUBLIC-KEY')
# For the gold relation there is also a path in the burst ('PUBLIC-KEY ENCRYPTION', 'PRIVATE-KEY')
# For the gold relation there is also a path in the burst ('PUBLIC-KEY ENCRYPTION', 'CERTIFICATE')
# For the gold relation there is also a path in the burst ('PUBLIC-KEY ENCRYPTION', 'CERTIFICATE AUTHORITY')
# For the gold relation there is also a path in the burst ('PUBLIC-KEY ENCRYPTION', 'DIGITAL SIGNATURE')
# For the gold relation there is also a path in the burst ('MNEMONIC ADDRESS', 'UNIFORM RESOURCE LOCATOR')
# For the gold relation there is also a path in the burst ('WIFI NETWORK', 'GATEWAY')
#
# TP = 668
# FP = 439
# TN = 18398
# FN = 1827
# FNHP = 0 precision = 0.6034327009936766
# recall = 0.26773547094188377
# precision = 0.6034327009936766
# recall = 0.26773547094188377
# F1 = 0.37090505274847313
# number of paths TP 413

# %%
#compute_metrics(burst, gold)

# %%
#compute_metrics(burst_top, gold)

# %% [markdown]
# ## Co-occurrence

# %%
# file with occurrences
index_df = pd.read_csv("april_2020_index_con_collision_detection.csv", sep="\t", encoding="utf-8", usecols=[0,3,4,5])
index_df.head()
# Out:
#                                                Lemma  idFrase  idParolaStart  \
# 0  CARRIER SENSE , MULTIPLE ACCESS WITH COLLISION...       57              6
# 1  CARRIER SENSE , MULTIPLE ACCESS WITH COLLISION...      531             13
# 2  CARRIER SENSE , MULTIPLE ACCESS WITH COLLISION...       43             23
# 3  CARRIER SENSE , MULTIPLE ACCESS WITH COLLISION...       51              9
# 4  CARRIER SENSE , MULTIPLE ACCESS WITH COLLISION...       52              3
#
#    Lunghezza
# 0          8
# 1          8
# 2          8
# 3          8
# 4          8

# %%
# build undirected matrix from occurrences
# TAKES TIME! USE PRE-COMPUTED MATRIX SAVED IN CSV FILE
#freq_df = build_freq_matrix(index_df, save=False)
freq_df = pd.read_csv("risultati_freq\\freq.csv", sep="\t", encoding="utf-8", index_col=0)
freq_df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-3dc8495d2aa2> in <module>
#       2 # TAKES TIME! USE PRE-COMPUTED MATRIX SAVED IN CSV FILE
#       3 #freq_df = build_freq_matrix(index_df, save=False)
# ----> 4 freq_df = pd.read_csv("risultati_freq\\freq.csv", sep="\t", encoding="utf-8", index_col=0)
#       5 freq_df.head()
#       6
#
# ~/python-virtual-env/pret-venv/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     700                     skip_blank_lines=skip_blank_lines)
#     701
# --> 702         return _read(filepath_or_buffer, kwds)
#     703
#     704     parser_f.__name__ = name
#
# ~/python-virtual-env/pret-venv/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     427
#     428     # Create the parser.
# --> 429     parser = TextFileReader(filepath_or_buffer, **kwds)
#     430
#     431     if chunksize or iterator:
#
# ~/python-virtual-env/pret-venv/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options['has_index_names'] = kwds['has_index_names']
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# ~/python-virtual-env/pret-venv/lib/python3.6/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1120     def _make_engine(self, engine='c'):
#    1121         if engine == 'c':
# -> 1122             self._engine = CParserWrapper(self.f, **self.options)
#    1123         else:
#    1124             if engine == 'python':
#
# ~/python-virtual-env/pret-venv/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1851         kwds['usecols'] = self.usecols
#    1852
# -> 1853         self._reader = parsers.TextReader(src, **kwds)
#    1854         self.unnamed_cols = self._reader.unnamed_cols
#    1855
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'risultati_freq\\freq.csv' does not exist: b'risultati_freq\\freq.csv'

# %%
# give directionality to co-occurrence using temporal order

freq_rels = []

for c1 in concepts:
    for c2 in concepts:
        
        if freq_df.at[c1, c2] != 0 and freq_df.at[c2, c1] != 0:
            
            sub_df_c1 = index_df[index_df["Lemma"] == c1]
            sub_df_c2 = index_df[index_df["Lemma"] == c2]
            
            if sub_df_c1["idFrase"].min() < sub_df_c2["idFrase"].min():
                freq_rels.append((c1, c2, freq_df.at[c1, c2]))
            elif sub_df_c1["idFrase"].min() > sub_df_c2["idFrase"].min():
                freq_rels.append((c2, c1, freq_df.at[c2, c1]))
            
            # same sentence: check number of token
            elif sub_df_c1["idFrase"].min() == sub_df_c2["idFrase"].min():
                same_sent = sub_df_c1["idFrase"].min()
                sent_sub_df_c1 = index_df[(index_df["Lemma"] == c1) & (index_df["idFrase"] == same_sent)]
                sent_sub_df_c2 = index_df[(index_df["Lemma"] == c2) & (index_df["idFrase"] == same_sent)]
                
                if sent_sub_df_c1["idParolaStart"].min() < sent_sub_df_c2["idParolaStart"].min():
                    freq_rels.append((c1, c2, freq_df.at[c1, c2]))
                elif sent_sub_df_c1["idParolaStart"].min() > sent_sub_df_c2["idParolaStart"].min():
                    freq_rels.append((c2, c1, freq_df.at[c2, c1]))
                else:
                    print(c1, "\t->\t", c2, "\t", "not captured (1)")
            else:
                print(c1, "\t->\t", c2, "\t", "not captured (2)")
                
freq_rels_df = pd.DataFrame(freq_rels, columns=["prerequisite", "advanced", "count"])
freq_rels_df.head()

# %%
compute_metrics(freq_rels_df, gold)

# %% [markdown]
# ## Transitives

# %%
input_dir = "annotazioni_revisionate/nuove/"

trans = set()

for file in listdir(input_dir):
    
    curr_name = file.replace("Revisione_Annotazione2020_", "").replace(".csv", "")
    
    print(curr_name)
    
    trans_df = pd.read_excel("transitive_weak/dopo_revisione/transitive_dopo_revisione.xlsx", sheet_name=curr_name)
    trans = trans.union({tuple(x) for x in trans_df.values})
    
    print("\tNum of transitives:", len({tuple(x) for x in trans_df.values}))
    
print("\nNum of unique transitives:", len(trans))

gold_with_trans = {tuple(x) for x in gold.drop("count", axis=1, inplace=False).values}
gold_no_trans = gold_with_trans - trans
gold_no_trans = pd.DataFrame(data=list(gold_no_trans), columns=["prerequisite", "advanced"])
    
print("\nNum of relations in the combined gold with no transitives:", gold_no_trans.shape[0])               
gold_no_trans.head()

# %%
G_burst = create_graphs(burst)

diameter = nx.diameter(G_burst.to_undirected())
longest_path = nx.dag_longest_path_length(G_burst)
print("diameter:\t", diameter, "\nlongest path:\t", longest_path)

G_burst_no_trans = nx.dag.transitive_reduction(G_burst)
print("Burst after transitive reduction:\n", len(G_burst.edges()), "\t-->\t", len(G_burst_no_trans.edges()))

# %%
G_gold = create_graphs(gold_no_trans)

# if it's not a DAG we need to first delete cycles
try: 
    G_gold_no_trans = nx.dag.transitive_reduction(G_gold)
except nx.exception.NetworkXException:
    G_gold_no_trans = detect_and_remove_cycles(G_gold)

# %%
print("Gold after transitive reduction:\n", len(G_gold.edges()), "\t-->\t", len(G_gold_no_trans.edges()))

# %%
compute_metrics(G_burst_no_trans, G_gold_no_trans)
