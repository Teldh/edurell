# %%
import networkx as nx
import igraph as igraph
import pandas as pd
import numpy as np
from networkx.readwrite import json_graph
import json
import codecs
import csv
import ast
from collections import defaultdict

# %%
nesteddict = defaultdict(dict)
combined_terminology_set = set()
networkx_graph1 = nx.DiGraph()
networkx_graph2 = nx.DiGraph()
networkx_graph3 = nx.DiGraph()
networkx_graph4 = nx.DiGraph()
networkx_graph5 = nx.DiGraph()

transitive_dict= defaultdict(dict)

# %%
with open('../input_data/annotazioni2/frosina.json', 'r', encoding='utf-8') as json_data1:
    parsed_json1 = (json.loads(json_data1.read()))
    for internal_dic1 in parsed_json1["savedInsertedRelations"]:
        combined_terminology_set.add(internal_dic1["prerequisite"])
        combined_terminology_set.add(internal_dic1["advanced"]) 
with open('../input_data/annotazioni2/chiara.json', 'r', encoding='utf-8') as json_data2:
    parsed_json2 = (json.loads(json_data2.read()))
    for internal_dic2 in parsed_json2["savedInsertedRelations"]:
        combined_terminology_set.add(internal_dic2["prerequisite"])
        combined_terminology_set.add(internal_dic2["advanced"]) 
with open('../input_data/annotazioni2/samuele.json', 'r', encoding='utf-8') as json_data3:
    parsed_json3 = (json.loads(json_data3.read()))
    for internal_dic3 in parsed_json3["savedInsertedRelations"]:
        combined_terminology_set.add(internal_dic3["prerequisite"])
        combined_terminology_set.add(internal_dic3["advanced"])
with open('../input_data/annotazioni2/AndreaGarrone.json', 'r', encoding='utf-8') as json_data4:
    parsed_json4 = (json.loads(json_data4.read()))
    for internal_dic4 in parsed_json4["savedInsertedRelations"]:
        combined_terminology_set.add(internal_dic4["prerequisite"])
        combined_terminology_set.add(internal_dic4["advanced"])
with open('../input_data/annotazioni2/MarcoMochi.json', 'r', encoding='utf-8') as json_data5:
    parsed_json5 = (json.loads(json_data5.read()))
    for internal_dic5 in parsed_json5["savedInsertedRelations"]:
        combined_terminology_set.add(internal_dic5["prerequisite"])
        combined_terminology_set.add(internal_dic5["advanced"])
        
for i in combined_terminology_set:
    for j in combined_terminology_set:
        transitive_dict[i][j]= '0'
        
networkx_graph1.add_nodes_from(combined_terminology_set)  
networkx_graph2.add_nodes_from(combined_terminology_set)
networkx_graph3.add_nodes_from(combined_terminology_set)
networkx_graph4.add_nodes_from(combined_terminology_set)
networkx_graph5.add_nodes_from(combined_terminology_set)
        
# print('combined_terminology_set len:',len(combined_terminology_set))
# print(nesteddict)
# print(len(nesteddict))

with open('../input_data/annotazioni2/frosina.json', 'r', encoding='utf-8') as json_data1:
    parsed_json1 = (json.loads(json_data1.read()))
    for internal_dic in parsed_json1["savedInsertedRelations"]:
        prereq = internal_dic["prerequisite"]
        subsid = internal_dic["advanced"]
        if(internal_dic['weight']=="strong"):
            networkx_graph1.add_edge(prereq, subsid, weight=1)
            if(transitive_dict[prereq][subsid]=='0'):
                transitive_dict[prereq][subsid]='f_2'
            else:
                transitive_dict[prereq][subsid]=transitive_dict[prereq][subsid]+'f_2'
            
        elif(internal_dic['weight']=="weak"):
            networkx_graph1.add_edge(prereq, subsid, weight=0.5)
            if(transitive_dict[prereq][subsid]=='0'):
                transitive_dict[prereq][subsid]='f_1'
            else:
                transitive_dict[prereq][subsid]=transitive_dict[prereq][subsid]+'f_1'
            
        
with open('../input_data/annotazioni2/chiara.json', 'r', encoding='utf-8') as json_data2:
    parsed_json2 = (json.loads(json_data2.read()))
    for internal_dic in parsed_json2["savedInsertedRelations"]:
        prereq = internal_dic["prerequisite"]
        subsid = internal_dic["advanced"]
        if(internal_dic['weight']=="strong"):
            networkx_graph2.add_edge(prereq, subsid, weight=1)
            if(transitive_dict[prereq][subsid]=='0'):
                transitive_dict[prereq][subsid]='c_2'
            else:
                transitive_dict[prereq][subsid]=transitive_dict[prereq][subsid]+'c_2'
            
        elif(internal_dic['weight']=="weak"):
            networkx_graph2.add_edge(prereq, subsid, weight=0.5)
            if(transitive_dict[prereq][subsid]=='0'):
                transitive_dict[prereq][subsid]='c_1'
            else:
                transitive_dict[prereq][subsid]=transitive_dict[prereq][subsid]+'c_1'

with open('../input_data/annotazioni2/samuele.json', 'r', encoding='utf-8') as json_data3:
    parsed_json3 = (json.loads(json_data3.read()))
    for internal_dic in parsed_json3["savedInsertedRelations"]:
        prereq = internal_dic["prerequisite"]
        subsid = internal_dic["advanced"]
        if(internal_dic['weight']=="strong"):
            networkx_graph3.add_edge(prereq, subsid, weight=1)
            if(transitive_dict[prereq][subsid]=='0'):
                transitive_dict[prereq][subsid]='s_2'
            else:
                transitive_dict[prereq][subsid]=transitive_dict[prereq][subsid]+'s_2'
            
        elif(internal_dic['weight']=="weak"):
            networkx_graph3.add_edge(prereq, subsid, weight=0.5)
            if(transitive_dict[prereq][subsid]=='0'):
                transitive_dict[prereq][subsid]='s_1'
            else:
                transitive_dict[prereq][subsid]=transitive_dict[prereq][subsid]+'s_1'
    
with open('../input_data/annotazioni2/AndreaGarrone.json', 'r', encoding='utf-8') as json_data4:
    parsed_json4 = (json.loads(json_data4.read()))
    for internal_dic in parsed_json4["savedInsertedRelations"]:
        prereq = internal_dic["prerequisite"]
        subsid = internal_dic["advanced"]
        if(internal_dic['weight']=="strong"):
            networkx_graph4.add_edge(prereq, subsid, weight=1)
            if(transitive_dict[prereq][subsid]=='0'):
                transitive_dict[prereq][subsid]='a_2'
            else:
                transitive_dict[prereq][subsid]=transitive_dict[prereq][subsid]+'a_2'
            
        elif(internal_dic['weight']=="weak"):
            networkx_graph4.add_edge(prereq, subsid, weight=0.5)
            if(transitive_dict[prereq][subsid]=='0'):
                transitive_dict[prereq][subsid]='a_1'
            else:
                transitive_dict[prereq][subsid]=transitive_dict[prereq][subsid]+'a_1'
    
with open('../input_data/annotazioni2/MarcoMochi.json', 'r', encoding='utf-8') as json_data5:
    parsed_json5 = (json.loads(json_data5.read()))
    for internal_dic in parsed_json5["savedInsertedRelations"]:
        prereq = internal_dic["prerequisite"]
        subsid = internal_dic["advanced"]
        if(internal_dic['weight']=="strong"):
            networkx_graph5.add_edge(prereq, subsid, weight=1)
            if(transitive_dict[prereq][subsid]=='0'):
                transitive_dict[prereq][subsid]='m_2'
            else:
                transitive_dict[prereq][subsid]=transitive_dict[prereq][subsid]+'m_2'
            
        elif(internal_dic['weight']=="weak"):
            networkx_graph5.add_edge(prereq, subsid, weight=0.5)
            if(transitive_dict[prereq][subsid]=='0'):
                transitive_dict[prereq][subsid]='m_1'
            else:
                transitive_dict[prereq][subsid]=transitive_dict[prereq][subsid]+'m_1'

# %%
def detect_transitive_edges(graph, cutoff, find_also_not_inserted=False):
 
        # Detect transitive relations manually inserted by the annotator.
        # If "find_also_not_inserted", the algorithm searches also all the
        # potential transitives in the graph (before a cutoff).
        # 
        # INPUT:
        # graph
        # cutoff: an int number of edges, after which the searching algorithm stops.
        # 
        # OUTPUT
        # A dict with transitives,
        # indexed whether they have been manually inserted by the annotator
        # or automatically detected in the graph by the search algorithm.
        
    transitives = {'manually inserted': [],
                    'automatically detected': []}
        
    if cutoff > 14:
        cutoff = 14
    
    for source_node in graph.nodes():
        other_nodes = list(graph.nodes())
        other_nodes.remove(source_node)
    
        for target_node in other_nodes:
            paths = nx.all_simple_paths(graph, source_node, target_node, cutoff)
            
            for path in paths:
                if len(path)>2 and graph.has_edge(source_node, target_node):
                    # print(list(path))
                    if (source_node, target_node) not in transitives['manually inserted']:
                        transitives['manually inserted'].append((source_node, target_node))
                        
                    else:
                        if find_also_not_inserted:
                                if (source_node, target_node) not in transitives['automatically detected']:
                                    transitives['automatically detected'].append((source_node, target_node))
                        
    return transitives

# %%
# Frosina
transitive_result1 = detect_transitive_edges(networkx_graph1, 14, False)
len(transitive_result1['manually inserted'])
with open('transitive-frosina.csv', 'w') as f:
    for el in transitive_result1['manually inserted']:
        f.write("%s,%s\n" % el)
for el in transitive_result1['manually inserted']:
        prereq = el[0]
        subsid = el[1]
        # weak
        if(transitive_dict[prereq][subsid].find("f_1")!=-1):
            transitive_dict[prereq][subsid]=transitive_dict[prereq][subsid].replace("f_1", "ft_1")
            print("F: weak & trans:",prereq, subsid,transitive_dict[prereq][subsid])
        # strong
        elif(transitive_dict[prereq][subsid].find("f_2")!=-1):
            transitive_dict[prereq][subsid]=transitive_dict[prereq][subsid].replace("f_2", "ft_2")
            print("F: strong & trans:",prereq, subsid,transitive_dict[prereq][subsid])

# Chiara
transitive_result2 = detect_transitive_edges(networkx_graph2, 14, False)
len(transitive_result2['manually inserted'])
with open('transitive-chiara.csv', 'w') as f:
    for el in transitive_result2['manually inserted']:
        f.write("%s,%s\n" % el)
for el in transitive_result2['manually inserted']:
        prereq = el[0]
        subsid = el[1]
        # weak
        if(transitive_dict[prereq][subsid].find("c_1")!=-1):
            transitive_dict[prereq][subsid]=transitive_dict[prereq][subsid].replace("c_1", "ct_1")
            print("C: weak & trans:",prereq, subsid,transitive_dict[prereq][subsid])
        # strong
        elif(transitive_dict[prereq][subsid].find("c_2")!=-1):
            transitive_dict[prereq][subsid]=transitive_dict[prereq][subsid].replace("c_2", "ct_2")
            print("C: strong & trans:",prereq, subsid,transitive_dict[prereq][subsid])
            
# Samuele
transitive_result3 = detect_transitive_edges(networkx_graph3, 14, False)
len(transitive_result3['manually inserted'])
with open('transitive-samuele.csv', 'w') as f:
    for el in transitive_result3['manually inserted']:
        f.write("%s,%s\n" % el)
for el in transitive_result3['manually inserted']:
        prereq = el[0]
        subsid = el[1]
        # weak
        if(transitive_dict[prereq][subsid].find("s_1")!=-1):
            transitive_dict[prereq][subsid]=transitive_dict[prereq][subsid].replace("s_1", "st_1")
            print("S: weak & trans:",prereq, subsid,transitive_dict[prereq][subsid])
        # strong
        elif(transitive_dict[prereq][subsid].find("s_2")!=-1):
            transitive_dict[prereq][subsid]=transitive_dict[prereq][subsid].replace("s_2", "st_2")
            print("S: strong & trans:",prereq, subsid,transitive_dict[prereq][subsid])
            
# Andrea
transitive_result4 = detect_transitive_edges(networkx_graph4, 14, False)
len(transitive_result4['manually inserted'])
with open('transitive-andrea.csv', 'w') as f:
    for el in transitive_result4['manually inserted']:
        f.write("%s,%s\n" % el)
for el in transitive_result4['manually inserted']:
        prereq = el[0]
        subsid = el[1]
        # weak
        if(transitive_dict[prereq][subsid].find("a_1")!=-1):
            transitive_dict[prereq][subsid]=transitive_dict[prereq][subsid].replace("a_1", "at_1")
            print("A: weak & trans:",prereq, subsid,transitive_dict[prereq][subsid])
        # strong
        elif(transitive_dict[prereq][subsid].find("a_2")!=-1):
            transitive_dict[prereq][subsid]=transitive_dict[prereq][subsid].replace("a_2", "at_2")
            print("A: strong & trans:",prereq, subsid,transitive_dict[prereq][subsid])
            
# Marco
transitive_result5 = detect_transitive_edges(networkx_graph5, 14, False)
len(transitive_result5['manually inserted'])
with open('transitive-marco.csv', 'w') as f:
    for el in transitive_result5['manually inserted']:
        f.write("%s,%s\n" % el)
for el in transitive_result5['manually inserted']:
        prereq = el[0]
        subsid = el[1]
        # weak
        if(transitive_dict[prereq][subsid].find("m_1")!=-1):
            transitive_dict[prereq][subsid]=transitive_dict[prereq][subsid].replace("m_1", "mt_1")
            print("M: weak & trans:",prereq, subsid,transitive_dict[prereq][subsid])
        # strong
        elif(transitive_dict[prereq][subsid].find("m_2")!=-1):
            transitive_dict[prereq][subsid]=transitive_dict[prereq][subsid].replace("m_2", "mt_2")
            print("M: strong & trans:",prereq, subsid,transitive_dict[prereq][subsid])
# Out:
# F: weak & trans: TRANSPORT_LAYER NETWORK_LAYER ft_1c_2c_2s_1
# F: strong & trans: TRANSPORT_LAYER USER_DATAGRAM_PROTOCOL ft_2c_2s_2s_2m_2
# F: strong & trans: TRADITIONAL_TELEPHONE ANALOG_TELEPHONE_ADAPTER ft_2
# F: strong & trans: STAR_NETWORK CARRIER_SENSE_,_MULTIPLE_ACCESS_WITH_COLLISION_AVOIDANCE ft_2
# F: weak & trans: NETWORK_LAYER INTERNET_PROTOCOL_VERSION_FOUR ft_1
# F: strong & trans: ROUTER NETWORK_LAYER ft_2c_2s_2s_2a_2m_2
# F: strong & trans: ROUTER HOP_COUNT ft_2m_2
# F: strong & trans: SERVER NAME_SERVER ft_2c_2s_2a_2a_2a_2a_2a_2a_2a_2a_2a_2m_2
# F: strong & trans: SERVER SERVER-SIDE_ACTIVITY ft_2c_2c_2s_2a_2a_2a_2a_2a_2a_2a_2a_2m_2
# F: strong & trans: WIRELESS_TELEPHONE 4G ft_2
# F: strong & trans: BUS_NETWORK BRIDGE ft_2c_2
# F: strong & trans: BUS_NETWORK SWITCH ft_2c_2c_2
# F: strong & trans: NOTATIONAL_SYSTEM MARKUP_LANGUAGE ft_2s_2
# F: strong & trans: DEVICE ROUTER ft_2s_2
# F: weak & trans: DEVICE END_SYSTEM ft_1s_2
# F: strong & trans: DEVICE BRIDGE ft_2s_2
# ...

# %%
# writing Weights and Transitive UNION MATRIX
with open('weak_&_transitives.csv', 'w') as f:
    writer = csv.writer(f)
    writer.writerow(combined_terminology_set)
    for k_ex,v_ex in transitive_dict.items():
        row=[]
        for k_in, v_in in v_ex.items():
            # print("[k] + v",v_in)
            row.append(v_in)
        writer.writerow(row)
